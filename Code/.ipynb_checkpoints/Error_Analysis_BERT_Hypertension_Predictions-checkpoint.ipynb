# %% [markdown]
# ## Error Analysis for Hypertension Tag Predictions

# %%
import os
import string
import random
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
import numpy as np

# %% [markdown]
# ### Test LABELS for TOKENS in TEST Dataset against BERT Outputs
#
# BERT Classifier has returned results for the tokens passed in 'test.tsv' file.  The returned values are probabilities, that need to be converted into equivalent class labels based on majority class.  Then, the class label should be compared against the actual label from the code above to extract the IO-Coding from the xml files.  This is a brute-force approach or a manual way of verifying the validity of the predictions

# %% [markdown]
# Read in results from BERT Predicitons to the above dataset
# The above dataset is derived from IO-Coding applied as done on the training set. This is what should be based on the annotation process. Nowe, we have to read in the predictions from bert, which is a set of class probabilities across all 3 classes and we have to merget that with the above dataset for comparison and error analysis.

# %% [markdown]
# ### Data File Names

# %% [markdown]
# * Test files with Labels and Filenames : /data_for_bert_sent/test_files_with_labels/*_testfile.csv
# * Bert label mapping /data_for_bert_sent/test_files_with_labels/*_labelmapping.csv
# * BERT evaluation /data_for_bert_sent/BERT_run_results/*_eval_results.txt

# %%
print(os.path.dirname(os.path.abspath('__file__')))
# Out:
# C:\Users\Kalyan\Documents\Anu\W266 - NLP\Final Project\lheart-disease-risk-prediction\Code

# %%
# read in the test files with labels

HI_test = pd.read_csv("data_for_bert_sent/test_files_with_labels/hypertension_ind_testfile.csv")

# %%
HI_test.head(10)
# Out:
#    Unnamed: 0                                           sentence    label  \
# 0           0                            Record date: 2069-04-07    Other
# 1           1                        Mr. Villegas is seen today.    Other
# 2           2                I have not seen him since November.    Other
# 3           3  About three weeks ago he stopped his Prednison...    Other
# 4           4                             he was gaining weight.    Other
# 5           5                He does feel that his shoulders are    Other
# 6           6                               definitely improved.    Other
# 7           7      It is unclear what he is actually taking, but    Other
# 8           8  I think based on the color of his pills and th...    Other
# 9           9  medication that he continues taking his Atenol...  mention
#
#          file
# 0  110-01.xml
# 1  110-01.xml
# 2  110-01.xml
# 3  110-01.xml
# 4  110-01.xml
# 5  110-01.xml
# 6  110-01.xml
# 7  110-01.xml
# 8  110-01.xml
# 9  110-01.xml

# %%
# read in the test results captured for BERT Hypertension model and specify columns as the actual file has no header
bert_HI_results = pd.read_csv("data_for_bert_sent/BERT_run_results/sentence_based_output_data_hypertension_output_results_test_results.tsv", sep='\t',header=None)
 
bert_HI_results.columns=["Class0", "Class1", "Class2"]

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2
# 0  0.999976  0.000010  0.000015
# 1  0.999977  0.000009  0.000014
# 2  0.999973  0.000010  0.000017
# 3  0.999975  0.000009  0.000015
# 4  0.999976  0.000010  0.000015

# %%
bert_HI_results['predClass'] = bert_HI_results.idxmax(axis=1)

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2 predClass
# 0  0.999976  0.000010  0.000015    Class0
# 1  0.999977  0.000009  0.000014    Class0
# 2  0.999973  0.000010  0.000017    Class0
# 3  0.999975  0.000009  0.000015    Class0
# 4  0.999976  0.000010  0.000015    Class0

# %%
bert_HI_results['predClass'].value_counts()
# Out:
# Class0    36653
# Class2      757
# Class1      228
# Name: predClass, dtype: int64

# %%
def HI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'high bp'
    elif (classlabel=='Class2'):
        return 'mention'
    else:
        return 'Other'

# %%
bert_HI_results['predLabel'] = bert_HI_results['predClass'].apply(HI_set_labels)

bert_HI_results.head(10)
# Out:
#      Class0    Class1    Class2 predClass predLabel
# 0  0.999976  0.000010  0.000015    Class0     Other
# 1  0.999977  0.000009  0.000014    Class0     Other
# 2  0.999973  0.000010  0.000017    Class0     Other
# 3  0.999975  0.000009  0.000015    Class0     Other
# 4  0.999976  0.000010  0.000015    Class0     Other
# 5  0.999977  0.000010  0.000013    Class0     Other
# 6  0.999976  0.000010  0.000014    Class0     Other
# 7  0.999975  0.000010  0.000016    Class0     Other
# 8  0.999976  0.000011  0.000013    Class0     Other
# 9  0.016559  0.001651  0.981791    Class2   mention

# %%
# validating the counts by label
bert_HI_results['predLabel'].value_counts()
# Out:
# Other      36653
# mention      757
# high bp      228
# Name: predLabel, dtype: int64

# %%
HI_combined = pd.concat([HI_test, bert_HI_results], axis=1)

# %%
HI_combined.head()
# Out:
#    Unnamed: 0                                           sentence  label  \
# 0           0                            Record date: 2069-04-07  Other
# 1           1                        Mr. Villegas is seen today.  Other
# 2           2                I have not seen him since November.  Other
# 3           3  About three weeks ago he stopped his Prednison...  Other
# 4           4                             he was gaining weight.  Other
#
#          file    Class0    Class1    Class2 predClass predLabel
# 0  110-01.xml  0.999976  0.000010  0.000015    Class0     Other
# 1  110-01.xml  0.999977  0.000009  0.000014    Class0     Other
# 2  110-01.xml  0.999973  0.000010  0.000017    Class0     Other
# 3  110-01.xml  0.999975  0.000009  0.000015    Class0     Other
# 4  110-01.xml  0.999976  0.000010  0.000015    Class0     Other

# %%
HI_combined[HI_combined['predLabel']!='Other']
# Out:
#        Unnamed: 0                                           sentence    label  \
# 9               9  medication that he continues taking his Atenol...  mention
# 67             67                             Blood pressure 142/74.  high bp
# 75             75                                 (3)  Hypertension.  mention
# 105           105                                                HTN  mention
# 120           120  VS: T: 98.1  HR: 59  BP: 158/72  RR: 20  Sat: ...  high bp
# 190           190                                       HYPERTENSION  mention
# 273           273         dependent diabetes mellitus, hypertension.  mention
# 310           310  patient is a 58-year-old male with a history o...  mention
# 327           327  179/85, a pulse of 91, respirations of 20, and...  high bp
# 394           394  PAST MEDICAL HISTORY:  Hypertension, diabetes,...  mention
# 408           408  pressure 186/56, oxygen saturation 97%, and te...  high bp
# 429           429  history, his hypertension, and worsening kidne...  mention
# 450           450  He is a 54-year-old man with obesity, dyslipid...  mention
# 484           484  His initial blood pressure 149/96, but then 15...  high bp
# 521           521  PAST MEDICAL HISTORY:  Hypertension, multiple ...  mention
# 564           564  a history of hypertension, history of anemia a...  mention
# 678           678  sclerosis, bedridden, also has a history of hy...  mention
# 727           727  PAST MEDICAL HISTORY:  Remarkable for hyperten...  mention
# 847           847                                 hypertension, CHF.  mention
# 923           923  HPI: 57M who lives in NH and has h/o severe MS...  mention
# 995           995  Physical Exam:T 98.6 HR 150 BP 113/83 18-20 97...    Other
# 1032         1032  He went to Gilmore Hospital, where they checke...  high bp
# 1036         1036  They attempted to arrange for a renal angiogra...  mention
# 1044         1044                                      Hypertension.  mention
# 1062         1062                               HTN in mother, aunt.    Other
# 1095         1095  I have counseled him that most likely the best...  mention
# 1100         1100  He wishes to have a PCP at FPC, and I have req...  mention
# 1110         1110  He remains on ASA 325mg po qd for stroke preve...  mention
# 1130         1130  The best for of treatment would be continued a...  mention
# 1154         1154                                      Hypertension.  mention
# ...           ...                                                ...      ...
# 36460       36460                        Blood Pressure:\t 120/80       Other
# 36498       36498                                       HYPERTENSION  mention
# 36592       36592                                      Hypertension.  mention
# 36623       36623  Mrs Chapman  is here today to follow up on HTN...  mention
# 36625       36625                  I saw her 2/24/87 for HTN and DM.  mention
# 36655       36655                                      HYPERTENSION   mention
# 36695       36695                                       HYPERTENSION  mention
# 36729       36729  Mrs Chapman  is here today to follow up on HTN...  mention
# 36757       36757                                      HYPERTENSION   mention
# 36800       36800                                       HYPERTENSION  mention
# 36851       36851                                          BP 154/82  high bp
# 36917       36917  Mr Gillespie is a 53 yo man with a history of ...  mention
# 36945       36945                                       Hypertension  mention
# 36980       36980               Vitals  97.7  92  141/69  18  98% 3L  high bp
# 37002       37002  53 yo man with NIDDM and HTN presents with 5 d...  mention
# 37018       37018  ###HYPERTENSION &#8211; will switch lisinopril...  mention
# 37043       37043      Hypertension, on lisinopril 10 mg, Toprol XL   mention
# 37081       37081  In brief, this is a 54 y/o M hx neurofibromato...  mention
# 37090       37090                                                HTN  mention
# 37108       37108                                  BPs 90s systolic.    Other
# 37150       37150               pressure was 152/80 in her left arm.  high bp
# 37196       37196                                      Hypertension   mention
# 37227       37227                         BP 151/68, P 88, Wt 140 lb  high bp
# 37238       37238  HTn :    increase lisinopril to 20 mg, check c...  mention
# 37259       37259                                      Hypertension   mention
# 37319       37319  In the ED, VS: T 98.1 HR 100-114 BP95/55-172/7...  high bp
# 37395       37395                                             183/90  high bp
# 37499       37499               HTN: likely exacerbated by steroids.  mention
# 37619       37619  Impression: 89 year old male with past medical...  mention
# 37628       37628    HTN &#8211; continue Lasix, Losartan, and Lasix  mention
#
#              file    Class0    Class1    Class2 predClass predLabel
# 9      110-01.xml  0.016559  0.001651  0.981791    Class2   mention
# 67     110-02.xml  0.003116  0.995773  0.001111    Class1   high bp
# 75     110-02.xml  0.012952  0.001188  0.985861    Class2   mention
# 105    110-03.xml  0.007482  0.000758  0.991760    Class2   mention
# 120    110-03.xml  0.003169  0.995726  0.001105    Class1   high bp
# 190    110-04.xml  0.011669  0.001123  0.987208    Class2   mention
# 273    111-01.xml  0.010522  0.001211  0.988267    Class2   mention
# 310    111-02.xml  0.010370  0.001238  0.988393    Class2   mention
# 327    111-02.xml  0.003460  0.995402  0.001137    Class1   high bp
# 394    111-04.xml  0.009499  0.001182  0.989319    Class2   mention
# 408    111-04.xml  0.003068  0.995855  0.001077    Class1   high bp
# 429    111-04.xml  0.016980  0.001616  0.981404    Class2   mention
# 450    112-04.xml  0.008822  0.001478  0.989700    Class2   mention
# 484    112-05.xml  0.003181  0.995706  0.001114    Class1   high bp
# 521    113-01.xml  0.010780  0.001266  0.987954    Class2   mention
# 564    113-02.xml  0.014122  0.001360  0.984518    Class2   mention
# 678    113-02.xml  0.010744  0.001232  0.988023    Class2   mention
# 727    113-03.xml  0.011073  0.001295  0.987632    Class2   mention
# 847    113-04.xml  0.012384  0.001165  0.986451    Class2   mention
# 923    113-05.xml  0.006492  0.000997  0.992511    Class2   mention
# 995    113-05.xml  0.196388  0.801791  0.001821    Class1   high bp
# 1032   114-01.xml  0.003404  0.995498  0.001098    Class1   high bp
# 1036   114-01.xml  0.014413  0.001685  0.983902    Class2   mention
# 1044   114-01.xml  0.012146  0.001127  0.986727    Class2   mention
# 1062   114-01.xml  0.008756  0.000856  0.990388    Class2   mention
# 1095   114-01.xml  0.014140  0.001757  0.984103    Class2   mention
# 1100   114-01.xml  0.016093  0.001980  0.981927    Class2   mention
# 1110   114-02.xml  0.013854  0.001630  0.984516    Class2   mention
# 1130   114-02.xml  0.015994  0.001818  0.982188    Class2   mention
# 1154   114-03.xml  0.012146  0.001127  0.986727    Class2   mention
# ...           ...       ...       ...       ...       ...       ...
# 36460  386-01.xml  0.002737  0.995857  0.001407    Class1   high bp
# 36498  386-01.xml  0.011669  0.001123  0.987208    Class2   mention
# 36592  386-02.xml  0.012146  0.001127  0.986727    Class2   mention
# 36623  386-03.xml  0.008152  0.000929  0.990919    Class2   mention
# 36625  386-03.xml  0.007930  0.000904  0.991165    Class2   mention
# 36655  386-03.xml  0.011669  0.001123  0.987208    Class2   mention
# 36695  386-03.xml  0.011669  0.001123  0.987208    Class2   mention
# 36729  386-04.xml  0.008152  0.000929  0.990919    Class2   mention
# 36757  386-04.xml  0.011669  0.001123  0.987208    Class2   mention
# 36800  386-04.xml  0.011669  0.001123  0.987208    Class2   mention
# 36851  387-01.xml  0.003129  0.995749  0.001122    Class1   high bp
# 36917  387-02.xml  0.013505  0.001636  0.984859    Class2   mention
# 36945  387-02.xml  0.011669  0.001123  0.987208    Class2   mention
# 36980  387-02.xml  0.006891  0.991892  0.001217    Class1   high bp
# 37002  387-02.xml  0.007724  0.000921  0.991355    Class2   mention
# 37018  387-02.xml  0.024588  0.001977  0.973434    Class2   mention
# 37043  387-03.xml  0.014816  0.001421  0.983763    Class2   mention
# 37081  387-04.xml  0.006815  0.001076  0.992109    Class2   mention
# 37090  387-04.xml  0.007482  0.000758  0.991760    Class2   mention
# 37108  387-04.xml  0.059770  0.938653  0.001578    Class1   high bp
# 37150  388-01.xml  0.003410  0.995456  0.001134    Class1   high bp
# 37196  388-04.xml  0.011669  0.001123  0.987208    Class2   mention
# 37227  388-04.xml  0.003175  0.995670  0.001155    Class1   high bp
# 37238  388-04.xml  0.008922  0.000950  0.990127    Class2   mention
# 37259  388-05.xml  0.011669  0.001123  0.987208    Class2   mention
# 37319  389-02.xml  0.003554  0.995368  0.001078    Class1   high bp
# 37395  389-02.xml  0.003428  0.995444  0.001128    Class1   high bp
# 37499  389-02.xml  0.008744  0.000908  0.990348    Class2   mention
# 37619  389-04.xml  0.007278  0.000966  0.991755    Class2   mention
# 37628  389-04.xml  0.009544  0.000909  0.989547    Class2   mention
#
# [985 rows x 9 columns]

# %%
HI_test_labels = HI_combined['label']
HI_pred_labels = HI_combined['predLabel']

#print(type(HI_test_labels))

# %%
accuracy_score(HI_test_labels, HI_pred_labels)
# Out:
# 0.9953238748073755

# %%
print(classification_report(HI_pred_labels, HI_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       1.00      1.00      1.00     36653
#      high bp       0.85      0.82      0.83       228
#      mention       0.95      0.90      0.93       757
#
#    micro avg       1.00      1.00      1.00     37638
#    macro avg       0.93      0.91      0.92     37638
# weighted avg       1.00      1.00      1.00     37638

# %%
unique_label = np.unique(HI_test_labels)
print(pd.DataFrame(confusion_matrix(HI_test_labels, HI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#               pred:Other  pred:high bp  pred:mention
# true:Other         36591            41            69
# true:high bp          30           186             3
# true:mention          32             1           685

# %%
from sklearn.utils.multiclass import unique_labels

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")

    fig.tight_layout()
    return ax

plot_confusion_matrix(HI_test_labels, HI_pred_labels, ["Other", "high bp", "mention"])
plt.show()
# Out:
# Confusion matrix, without normalization
# [[36591    41    69]
#  [   30   186     3]
#  [   32     1   685]]

# %%
# read in the test files with labels

DT_test = pd.read_csv("data_for_bert_sent/test_files_with_labels/diabetes_time_testfile.csv")

# %%
DT_test.head(10)

# %%
# read in the test results captured for BERT Hypertension model and specify columns as the actual file has no header
bert_DT_results = pd.read_csv("data_for_bert_sent/BERT_run_results/diabetes_time_test_results.tsv", sep='\t',header=None)
 
bert_DT_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_DT_results.head()

# %%
bert_DT_results['predClass'] = bert_DT_results.idxmax(axis=1)

# %%
bert_DT_results.head()

# %%
bert_DT_results['predClass'].value_counts()

# %%
def DT_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'after DCT'
    elif (classlabel=='Class2'):
        return 'before DCT'
    elif (classlabel=='Class3'):
        return 'during DCT'
    else:
        return 'Other'

# %%
bert_DT_results['predLabel'] = bert_DT_results['predClass'].apply(DT_set_labels)

bert_DT_results.head(10)

# %%
# validating the counts by label
bert_DT_results['predLabel'].value_counts()

# %%
DT_combined = pd.concat([DT_test, bert_DT_results], axis=1)

# %%
DT_combined.head()

# %%
DT_combined[DT_combined['predLabel']!='Other']

# %%
DT_test_labels = DT_combined['label']
DT_pred_labels = DT_combined['predLabel']

#print(type(DT_test_labels))

# %%
accuracy_score(DT_test_labels, DT_pred_labels)

# %%
print(classification_report(DT_pred_labels, DT_test_labels))

# %%
print("Confusion Matrix \n", confusion_matrix(DT_test_labels, DT_pred_labels))

# %%
unique_label = np.unique(DT_test_labels)
print(pd.DataFrame(confusion_matrix(DT_test_labels, DT_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))

# %% [markdown]
# ### Interpreting the predictions compared against actual test labels
#
# As seen above, BERT predictions seem very accurate and it seems to predict only after it has seen the complete context.  Also, punctuation marks are not labeled as one of the relevant classes, although a human annotator has done based on the instructions provided as part of the annotation process.

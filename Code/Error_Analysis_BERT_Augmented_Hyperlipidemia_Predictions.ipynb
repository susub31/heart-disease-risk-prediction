# %% [markdown]
# ## Error Analysis for Hyperlipidemia Tag Predictions (BERT Augmented)

# %%
import os
import string
import random
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
import numpy as np

# %% [markdown]
# ### Test LABELS for TOKENS in TEST Dataset against BERT Outputs
#
# BERT Classifier has returned results for the tokens passed in 'test.tsv' file.  The returned values are probabilities, that need to be converted into equivalent class labels based on majority class.  Then, the class label should be compared against the actual label from the code above to extract the IO-Coding from the xml files.  This is a brute-force approach or a manual way of verifying the validity of the predictions

# %% [markdown]
# Read in results from BERT Predicitons to the above dataset
# The above dataset is derived from IO-Coding applied as done on the training set. This is what should be based on the annotation process. Nowe, we have to read in the predictions from bert, which is a set of class probabilities across all 3 classes and we have to merget that with the above dataset for comparison and error analysis.

# %% [markdown]
# ### Data File Names

# %% [markdown]
# * Test files with Labels and Filenames : /data_for_bert_sent/test_files_with_labels/*_testfile.csv
# * Bert label mapping /data_for_bert_sent/test_files_with_labels/*_labelmapping.csv
# * BERT evaluation /data_for_bert_sent/BERT_run_results/*_eval_results.txt

# %%
print(os.path.dirname(os.path.abspath('__file__')))
# Out:
# C:\Users\Kalyan\Documents\Anu\W266 - NLP\Final Project\lheart-disease-risk-prediction\Code

# %% [markdown]
# ### Hyperlipidemia Indicator

# %%
# read in the test files with labels

HI_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/hyperlipidemia_ind_testfile.csv")

# %%
HI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
HI_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...  Other
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Augmented Hyperlipidemia model and specify columns as the actual file has no header
bert_HI_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_hyperlipidemia_ind_output_results_test_results.tsv", sep='\t',header=None)
 
bert_HI_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2    Class3
# 0  0.999954  0.000017  0.000010  0.000019
# 1  0.999954  0.000015  0.000010  0.000021
# 2  0.999950  0.000017  0.000008  0.000026
# 3  0.999883  0.000023  0.000011  0.000083
# 4  0.994832  0.000295  0.000111  0.004762

# %%
bert_HI_results['predClass'] = bert_HI_results.idxmax(axis=1)

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2    Class3 predClass
# 0  0.999954  0.000017  0.000010  0.000019    Class0
# 1  0.999954  0.000015  0.000010  0.000021    Class0
# 2  0.999950  0.000017  0.000008  0.000026    Class0
# 3  0.999883  0.000023  0.000011  0.000083    Class0
# 4  0.994832  0.000295  0.000111  0.004762    Class0

# %%
bert_HI_results['predClass'].value_counts()
# Out:
# Class0    24910
# Class3      347
# Class1       22
# Class2        2
# Name: predClass, dtype: int64

# %%
def HI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'high LDL'
    elif (classlabel=='Class2'):
        return 'high chol.'
    elif (classlabel=='Class3'):
        return 'mention'
    else:
        return 'Other'

# %%
bert_HI_results['predLabel'] = bert_HI_results['predClass'].apply(HI_set_labels)

bert_HI_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3 predClass predLabel
# 0  0.999954  0.000017  0.000010  0.000019    Class0     Other
# 1  0.999954  0.000015  0.000010  0.000021    Class0     Other
# 2  0.999950  0.000017  0.000008  0.000026    Class0     Other
# 3  0.999883  0.000023  0.000011  0.000083    Class0     Other
# 4  0.994832  0.000295  0.000111  0.004762    Class0     Other
# 5  0.999956  0.000015  0.000009  0.000020    Class0     Other
# 6  0.999955  0.000014  0.000009  0.000021    Class0     Other
# 7  0.999955  0.000017  0.000010  0.000019    Class0     Other
# 8  0.999955  0.000013  0.000009  0.000023    Class0     Other
# 9  0.999954  0.000015  0.000009  0.000022    Class0     Other

# %%
# validating the counts by label
bert_HI_results['predLabel'].value_counts()
# Out:
# Other         24910
# mention         347
# high LDL         22
# high chol.        2
# Name: predLabel, dtype: int64

# %%
HI_combined = pd.concat([HI_test, bert_HI_results], axis=1)

# %%
HI_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999954  0.000017
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999954  0.000015
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999950  0.000017
# 3           3             MR:\t8249813  Other  110-03.xml  0.999883  0.000023
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.994832  0.000295
#
#      Class2    Class3 predClass predLabel
# 0  0.000010  0.000019    Class0     Other
# 1  0.000010  0.000021    Class0     Other
# 2  0.000008  0.000026    Class0     Other
# 3  0.000011  0.000083    Class0     Other
# 4  0.000111  0.004762    Class0     Other

# %%
HI_combined[HI_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence  \
# 18             18                                    Hyperlipidemia
# 104           104                                     hyperlipidemia
# 185           185  His past medical history is significant for hy...
# 227           227  His past medical history is significant for hy...
# 265           265  He is a 54-year-old man with obesity, dyslipid...
# 310           310                                  High cholesterol.
# 357           357              Mr. Slater is an 83 yo w/ h/o bull...
# 376           376                &#183;         Hypercholesterolemia
# 430           430  : Mr. Slater is an 83 yo w/ h/o bullous pemphi...
# 497           497                              Hyperlipidemia MAJOR
# 525           525                                     Hyperlipidemia
# 709           709                               Hypercholesterolemia
# 751           751  Cardiovascular: see HPI; hypertension; hyperch...
# 791           791  71 year old female with a history of diabetes,...
# 831           831  54 y/o Columbian speaking male with HTN, HL wh...
# 846           846                                                 HL
# 907           907  54 y/o Spanish speaking male with HTN, HL pres...
# 923           923                                     Hyperlipidemia
# 1004         1004  PMH: S/p mechanical aortic valve replacement, ...
# 1043         1043     55 y/o Columbian male with a history of HTN...
# 1101         1101                                    Hyperlipidemia.
# 1147         1147     55 y/o Columbian male with a history of HTN...
# 1220         1220           (1)  Angina/hypertension/hyperlipidemia.
# 1266         1266                              Hypercholesterolemia.
# 1371         1371                        Hyperlipidemia, on Lipitor.
# 1438         1438                                              - HLD
# 1523         1523  foot drop, anemia, sciatica, left thigh pain, ...
# 1639         1639                 elevated serum cholesterol\t
# 1814         1814                 elevated serum cholesterol
# 1907         1907  His PMH includes hypertension, hyperlipidemia,...
# ...           ...                                                ...
# 23858       23858  HPI: This is a 72-year-old right-handed woman ...
# 23872       23872                              Elevated cholesterol.
# 23955       23955  75-year-old woman with a history of hypertensi...
# 23969       23969                              Elevated cholesterol.
# 24087       24087  L stent 12/19Goiter  : multinodular, USG 2115A...
# 24091       24091  Hyperlipidemia - Taking gemfibrozil c good eff...
# 24113       24113  history of hypertension, hypercholesterolemia,...
# 24126       24126  PAST MEDICAL HISTORY:  Hypertension, hyperchol...
# 24188       24188  hypercholesterolemia presents to the emergency...
# 24203       24203  PAST MEDICAL HISTORY:  As noted above, hyperch...
# 24268       24268  HISTORY OF PRESENT ILLNESS:  Ms. Uhrich is a 7...
# 24275       24275  PAST MEDICAL HISTORY:  Notable for hypertensio...
# 24293       24293  In summary, Karson Uhrich is a 73-year-old wom...
# 24317       24317  Medical issues include osteopenia, hyperlipide...
# 24371       24371  Results05/03/2092 NA 139,  K 4.1,  CL 101,  CO...
# 24382       24382                                     Hyperlipidemia
# 24400       24400                                     Hyperlipidemia
# 24550       24550                                       LDL was 125.
# 24560       24560                              Elevated cholesterol.
# 24605       24605     Her LDL is 116 ono 2/87 and has DM, goal <100.
# 24741       24741                                     Hyperlipidemia
# 24814       24814  ###DYSLIPIDEMIA &#8211; simvastatin 20 mg dail...
# 24839       24839                       Elevated lipids - on statin
# 24886       24886                                                 HL
# 24956       24956                               Cholesterol was 315.
# 25026       25026                                       cholesterol.
# 25058       25058                                    Hyperlipidemia
# 25102       25102                HL;  check  cho profile on lipitor.
# 25121       25121                                    Hyperlipidemia
# 25262       25262  Impression: 89 year old male with past medical...
#
#             label        file    Class0    Class1    Class2    Class3  \
# 18        mention  110-03.xml  0.002504  0.000209  0.000205  0.997083
# 104       mention  110-04.xml  0.002504  0.000209  0.000205  0.997083
# 185       mention  112-02.xml  0.002225  0.000202  0.000216  0.997357
# 227       mention  112-03.xml  0.002225  0.000202  0.000216  0.997357
# 265       mention  112-04.xml  0.002099  0.000194  0.000223  0.997484
# 310       mention  114-03.xml  0.004025  0.000316  0.000198  0.995460
# 357       mention  114-04.xml  0.002201  0.000201  0.000221  0.997377
# 376       mention  114-04.xml  0.002187  0.000202  0.000209  0.997402
# 430       mention  114-04.xml  0.002185  0.000200  0.000221  0.997393
# 497       mention  115-04.xml  0.002561  0.000210  0.000203  0.997025
# 525       mention  115-04.xml  0.002504  0.000209  0.000205  0.997083
# 709       mention  117-02.xml  0.002297  0.000205  0.000207  0.997291
# 751       mention  117-02.xml  0.002084  0.000193  0.000219  0.997504
# 791       mention  117-02.xml  0.002021  0.000191  0.000219  0.997569
# 831       mention  118-01.xml  0.002663  0.000201  0.000208  0.996929
# 846       mention  118-01.xml  0.002331  0.000209  0.000210  0.997250
# 907       mention  118-01.xml  0.002254  0.000193  0.000219  0.997335
# 923       mention  118-01.xml  0.002504  0.000209  0.000205  0.997083
# 1004      mention  118-04.xml  0.002167  0.000194  0.000219  0.997420
# 1043      mention  118-05.xml  0.002092  0.000197  0.000222  0.997489
# 1101      mention  118-05.xml  0.002521  0.000207  0.000205  0.997066
# 1147      mention  118-05.xml  0.002081  0.000195  0.000223  0.997501
# 1220      mention  119-02.xml  0.002273  0.000198  0.000214  0.997315
# 1266      mention  130-01.xml  0.002255  0.000202  0.000209  0.997334
# 1371      mention  130-03.xml  0.002334  0.000201  0.000209  0.997256
# 1438      mention  130-04.xml  0.002310  0.000207  0.000208  0.997274
# 1523      mention  130-05.xml  0.002179  0.000197  0.000215  0.997408
# 1639        Other  131-01.xml  0.007655  0.000478  0.000200  0.991667
# 1814      mention  131-02.xml  0.007381  0.000459  0.000207  0.991953
# 1907      mention  131-03.xml  0.002068  0.000193  0.000223  0.997517
# ...           ...         ...       ...       ...       ...       ...
# 23858     mention  380-02.xml  0.001981  0.000190  0.000224  0.997605
# 23872     mention  380-02.xml  0.004142  0.000341  0.000206  0.995311
# 23955     mention  380-03.xml  0.001967  0.000189  0.000224  0.997619
# 23969     mention  380-03.xml  0.004142  0.000341  0.000206  0.995311
# 24087     mention  383-05.xml  0.002346  0.000208  0.000224  0.997222
# 24091     mention  383-05.xml  0.002330  0.000204  0.000213  0.997252
# 24113     mention  384-01.xml  0.002066  0.000194  0.000216  0.997524
# 24126     mention  384-01.xml  0.002080  0.000194  0.000217  0.997509
# 24188     mention  384-02.xml  0.002260  0.000200  0.000211  0.997329
# 24203     mention  384-02.xml  0.002173  0.000198  0.000211  0.997417
# 24268     mention  384-03.xml  0.002076  0.000197  0.000224  0.997503
# 24275     mention  384-03.xml  0.002080  0.000193  0.000218  0.997510
# 24293     mention  384-03.xml  0.002189  0.000202  0.000222  0.997386
# 24317     mention  384-04.xml  0.002144  0.000194  0.000222  0.997440
# 24371       Other  384-04.xml  0.007988  0.990696  0.000089  0.001227
# 24382     mention  385-05.xml  0.002504  0.000209  0.000205  0.997083
# 24400     mention  385-05.xml  0.002504  0.000209  0.000205  0.997083
# 24550    high LDL  386-02.xml  0.000162  0.999504  0.000197  0.000138
# 24560       Other  386-02.xml  0.004142  0.000341  0.000206  0.995311
# 24605    high LDL  386-03.xml  0.000777  0.998897  0.000108  0.000218
# 24741     mention  387-02.xml  0.002504  0.000209  0.000205  0.997083
# 24814     mention  387-02.xml  0.002800  0.000214  0.000220  0.996766
# 24839     mention  387-03.xml  0.003087  0.000237  0.000189  0.996487
# 24886     mention  387-04.xml  0.002331  0.000209  0.000210  0.997250
# 24956  high chol.  388-03.xml  0.000127  0.000210  0.999451  0.000213
# 25026       Other  388-03.xml  0.002352  0.000208  0.000346  0.997095
# 25058     mention  388-04.xml  0.002504  0.000209  0.000205  0.997083
# 25102     mention  388-04.xml  0.002233  0.000204  0.000210  0.997352
# 25121     mention  388-05.xml  0.002504  0.000209  0.000205  0.997083
# 25262     mention  389-04.xml  0.002068  0.000191  0.000225  0.997516
#
#       predClass   predLabel
# 18       Class3     mention
# 104      Class3     mention
# 185      Class3     mention
# 227      Class3     mention
# 265      Class3     mention
# 310      Class3     mention
# 357      Class3     mention
# 376      Class3     mention
# 430      Class3     mention
# 497      Class3     mention
# 525      Class3     mention
# 709      Class3     mention
# 751      Class3     mention
# 791      Class3     mention
# 831      Class3     mention
# 846      Class3     mention
# 907      Class3     mention
# 923      Class3     mention
# 1004     Class3     mention
# 1043     Class3     mention
# 1101     Class3     mention
# 1147     Class3     mention
# 1220     Class3     mention
# 1266     Class3     mention
# 1371     Class3     mention
# 1438     Class3     mention
# 1523     Class3     mention
# 1639     Class3     mention
# 1814     Class3     mention
# 1907     Class3     mention
# ...         ...         ...
# 23858    Class3     mention
# 23872    Class3     mention
# 23955    Class3     mention
# 23969    Class3     mention
# 24087    Class3     mention
# 24091    Class3     mention
# 24113    Class3     mention
# 24126    Class3     mention
# 24188    Class3     mention
# 24203    Class3     mention
# 24268    Class3     mention
# 24275    Class3     mention
# 24293    Class3     mention
# 24317    Class3     mention
# 24371    Class1    high LDL
# 24382    Class3     mention
# 24400    Class3     mention
# 24550    Class1    high LDL
# 24560    Class3     mention
# 24605    Class1    high LDL
# 24741    Class3     mention
# 24814    Class3     mention
# 24839    Class3     mention
# 24886    Class3     mention
# 24956    Class2  high chol.
# 25026    Class3     mention
# 25058    Class3     mention
# 25102    Class3     mention
# 25121    Class3     mention
# 25262    Class3     mention
#
# [371 rows x 10 columns]

# %%
HI_test_labels = HI_combined['label']
HI_pred_labels = HI_combined['predLabel']

#print(type(HI_test_labels))

# %%
accuracy_score(HI_test_labels, HI_pred_labels)
# Out:
# 0.9962422372532732

# %%
print(classification_report(HI_pred_labels, HI_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       1.00      1.00      1.00     24910
#     high LDL       0.48      0.73      0.58        22
#   high chol.       0.14      0.50      0.22         2
#      mention       0.91      0.90      0.90       347
#
#    micro avg       1.00      1.00      1.00     25281
#    macro avg       0.63      0.78      0.68     25281
# weighted avg       1.00      1.00      1.00     25281

# %%
unique_label = np.unique(HI_test_labels)
print(pd.DataFrame(confusion_matrix(HI_test_labels, HI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#                  pred:Other  pred:high LDL  pred:high chol.  pred:mention
# true:Other            24858              6                1            34
# true:high LDL            16             16                0             1
# true:high chol.           5              0                1             1
# true:mention             31              0                0           311

# %%
HI_combined[HI_combined['label'] =='high LDL']
# Out:
#        sentenceId                                           sentence  \
# 1641         1641                      181/39/112 WITH TG 149 11/85.
# 1642         1642                   194/42/123/4.6 WITH TG 147 7/86.
# 1643         1643                              12/88 188/42/118/4.5.
# 2825         2825                 Cholesterol-LDL   05/15/2090 165
# 3759         3759  Please see prior notes for full lipid analysis...
# 3891         3891                                            LDL 138
# 4543         4543  I restarted her on lipitor 20 mg po qd, given ...
# 4753         4753  and LDL from 09/15/83 was 154 with a total cho...
# 6186         6186  However, cholesterol now of 186, HDL 46, LDL 105.
# 6994         6994  11/95 TC 199, HDL 42, LDL 122, TG 171, and sim...
# 11443       11443  Lipid profile showed Cholesterol 210, Trig 59,...
# 11557       11557  His lipid panel from his hospitalization revea...
# 11875       11875                    Cholesterol-LDL 05/24/2095 101
# 12294       12294            PE:  WDWN BF NAD  Wt 135 lbs  BP 100/64
# 12304       12304  Throughout her hospitalization she lost a lot ...
# 12309       12309                            Cholesterol 225/68/135.
# 14258       14258  cholesterol of 229, triglyceride of 68, HDL 51...
# 15354       15354                 Cholesterol-LDL   07/17/2069 104
# 15458       15458     On 06/18/2070, total cholesterol 168, trigl...
# 15525       15525  Hyperlipidemia: 8/72 chol 169, Tgl 67, hdl 37,...
# 18743       18743  Fasting lipid analysis one year ago showed tot...
# 18932       18932  Fasting lipid analysis 18 months ago showed to...
# 19000       19000  Fasting lipid analysis 2 weeks ago showed tota...
# 19059       19059                                    and LDL of 110.
# 19167       19167                                     Last dLDL 108.
# 19269       19269                         LDL from last May was 164.
# 19410       19410                              Last LDL  134 on 6/28
# 21627       21627  -increased lipitor to 20 (patient's Chol 179 a...
# 22780       22780   His lipid profile from 4/71 showed a LDL of 103.
# 22847       22847   His lipid profile from 4/71 showed a LDL of 103.
# 23623       23623      Calculated LDL         161*  50-160 mg/dL ...
# 24550       24550                                       LDL was 125.
# 24605       24605     Her LDL is 116 ono 2/87 and has DM, goal <100.
#
#           label        file    Class0    Class1    Class2    Class3 predClass  \
# 1641   high LDL  131-01.xml  0.999955  0.000015  0.000008  0.000022    Class0
# 1642   high LDL  131-01.xml  0.999955  0.000014  0.000009  0.000022    Class0
# 1643   high LDL  131-01.xml  0.999956  0.000015  0.000009  0.000020    Class0
# 2825   high LDL  134-03.xml  0.000151  0.999499  0.000215  0.000135    Class1
# 3759   high LDL  138-03.xml  0.002036  0.997454  0.000256  0.000255    Class1
# 3891   high LDL  139-02.xml  0.000178  0.999498  0.000180  0.000145    Class1
# 4543   high LDL  162-04.xml  0.999865  0.000028  0.000017  0.000090    Class0
# 4753   high LDL  163-03.xml  0.000268  0.999434  0.000148  0.000150    Class1
# 6186   high LDL  169-01.xml  0.000139  0.999488  0.000249  0.000124    Class1
# 6994   high LDL  193-05.xml  0.999933  0.000018  0.000010  0.000038    Class0
# 11443  high LDL  211-01.xml  0.389903  0.603864  0.002872  0.003361    Class1
# 11557  high LDL  211-02.xml  0.999395  0.000085  0.000032  0.000489    Class0
# 11875  high LDL  214-01.xml  0.000856  0.998807  0.000100  0.000238    Class1
# 12294  high LDL  216-03.xml  0.999954  0.000014  0.000009  0.000023    Class0
# 12304  high LDL  216-03.xml  0.999954  0.000016  0.000009  0.000021    Class0
# 12309  high LDL  216-03.xml  0.999896  0.000022  0.000019  0.000063    Class0
# 14258  high LDL  236-02.xml  0.000184  0.999471  0.000214  0.000130    Class1
# 15354  high LDL  260-02.xml  0.000205  0.999486  0.000164  0.000144    Class1
# 15458  high LDL  260-03.xml  0.999724  0.000074  0.000015  0.000187    Class0
# 15525  high LDL  260-04.xml  0.002247  0.000209  0.000207  0.997337    Class3
# 18743  high LDL  318-01.xml  0.999731  0.000083  0.000051  0.000135    Class0
# 18932  high LDL  318-03.xml  0.999852  0.000041  0.000028  0.000080    Class0
# 19000  high LDL  318-04.xml  0.999833  0.000042  0.000031  0.000094    Class0
# 19059  high LDL  319-01.xml  0.000134  0.999485  0.000251  0.000130    Class1
# 19167  high LDL  319-03.xml  0.999955  0.000015  0.000009  0.000021    Class0
# 19269  high LDL  340-03.xml  0.000165  0.999499  0.000198  0.000138    Class1
# 19410  high LDL  342-04.xml  0.999934  0.000022  0.000009  0.000035    Class0
# 21627  high LDL  372-02.xml  0.001590  0.997898  0.000238  0.000273    Class1
# 22780  high LDL  376-01.xml  0.155540  0.842182  0.000571  0.001708    Class1
# 22847  high LDL  376-02.xml  0.155540  0.842182  0.000571  0.001708    Class1
# 23623  high LDL  379-05.xml  0.999948  0.000016  0.000008  0.000029    Class0
# 24550  high LDL  386-02.xml  0.000162  0.999504  0.000197  0.000138    Class1
# 24605  high LDL  386-03.xml  0.000777  0.998897  0.000108  0.000218    Class1
#
#       predLabel
# 1641      Other
# 1642      Other
# 1643      Other
# 2825   high LDL
# 3759   high LDL
# 3891   high LDL
# 4543      Other
# 4753   high LDL
# 6186   high LDL
# 6994      Other
# 11443  high LDL
# 11557     Other
# 11875  high LDL
# 12294     Other
# 12304     Other
# 12309     Other
# 14258  high LDL
# 15354  high LDL
# 15458     Other
# 15525   mention
# 18743     Other
# 18932     Other
# 19000     Other
# 19059  high LDL
# 19167     Other
# 19269  high LDL
# 19410     Other
# 21627  high LDL
# 22780  high LDL
# 22847  high LDL
# 23623     Other
# 24550  high LDL
# 24605  high LDL

# %% [markdown]
# The entire class of 'high LDL' is getting predicted incorrectly as the model is not able to learn from the actual limits that determine high LDL levels.

# %% [markdown]
# ### Hyperlipidemia Time

# %%
# read in the test files with labels

HT_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/hyperlipidemia_tim_testfile.csv")

# %%
HT_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
HT_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...  Other
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Augmented Hyperlipidemia model and specify columns as the actual file has no header
bert_aug_HT_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_hyperlipidemia_time_output_results_test_results.tsv", sep='\t',header=None)
 
bert_aug_HT_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_aug_HT_results.head()
# Out:
#      Class0    Class1    Class2    Class3
# 0  0.999958  0.000012  0.000013  0.000018
# 1  0.999957  0.000011  0.000013  0.000019
# 2  0.999951  0.000010  0.000015  0.000024
# 3  0.999879  0.000014  0.000039  0.000068
# 4  0.999838  0.000019  0.000050  0.000092

# %%
bert_aug_HT_results['predClass'] = bert_aug_HT_results.idxmax(axis=1)

# %%
bert_aug_HT_results.head()
# Out:
#      Class0    Class1    Class2    Class3 predClass
# 0  0.999958  0.000012  0.000013  0.000018    Class0
# 1  0.999957  0.000011  0.000013  0.000019    Class0
# 2  0.999951  0.000010  0.000015  0.000024    Class0
# 3  0.999879  0.000014  0.000039  0.000068    Class0
# 4  0.999838  0.000019  0.000050  0.000092    Class0

# %%
bert_aug_HT_results['predClass'].value_counts()
# Out:
# Class0    24883
# Class3      202
# Class2      123
# Class1       73
# Name: predClass, dtype: int64

# %%
def HT_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'after DCT'
    elif (classlabel=='Class2'):
        return 'before DCT'
    elif (classlabel=='Class3'):
        return 'during DCT'
    else:
        return 'Other'

# %%
bert_aug_HT_results['predLabel'] = bert_aug_HT_results['predClass'].apply(HT_set_labels)

bert_aug_HT_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3 predClass predLabel
# 0  0.999958  0.000012  0.000013  0.000018    Class0     Other
# 1  0.999957  0.000011  0.000013  0.000019    Class0     Other
# 2  0.999951  0.000010  0.000015  0.000024    Class0     Other
# 3  0.999879  0.000014  0.000039  0.000068    Class0     Other
# 4  0.999838  0.000019  0.000050  0.000092    Class0     Other
# 5  0.999957  0.000013  0.000013  0.000018    Class0     Other
# 6  0.999955  0.000011  0.000014  0.000020    Class0     Other
# 7  0.999957  0.000011  0.000013  0.000020    Class0     Other
# 8  0.999958  0.000011  0.000014  0.000016    Class0     Other
# 9  0.999953  0.000014  0.000016  0.000017    Class0     Other

# %%
# validating the counts by label
bert_aug_HT_results['predLabel'].value_counts()
# Out:
# Other         24883
# during DCT      202
# before DCT      123
# after DCT        73
# Name: predLabel, dtype: int64

# %%
HT_combined = pd.concat([HT_test, bert_aug_HT_results], axis=1)

# %%
HT_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999958  0.000012
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999957  0.000011
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999951  0.000010
# 3           3             MR:\t8249813  Other  110-03.xml  0.999879  0.000014
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.999838  0.000019
#
#      Class2    Class3 predClass predLabel
# 0  0.000013  0.000018    Class0     Other
# 1  0.000013  0.000019    Class0     Other
# 2  0.000015  0.000024    Class0     Other
# 3  0.000039  0.000068    Class0     Other
# 4  0.000050  0.000092    Class0     Other

# %%
HT_combined[HT_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence  \
# 18             18                                    Hyperlipidemia
# 104           104                                     hyperlipidemia
# 185           185  His past medical history is significant for hy...
# 227           227  His past medical history is significant for hy...
# 265           265  He is a 54-year-old man with obesity, dyslipid...
# 310           310                                  High cholesterol.
# 357           357              Mr. Slater is an 83 yo w/ h/o bull...
# 376           376                &#183;         Hypercholesterolemia
# 430           430  : Mr. Slater is an 83 yo w/ h/o bullous pemphi...
# 496           496                               Hyperuricemia MAJOR
# 497           497                              Hyperlipidemia MAJOR
# 523           523                                      Hyperuricemia
# 525           525                                     Hyperlipidemia
# 531           531                                          Dysthymia
# 539           539                               Hyperhomocysteinemia
# 709           709                               Hypercholesterolemia
# 751           751  Cardiovascular: see HPI; hypertension; hyperch...
# 791           791  71 year old female with a history of diabetes,...
# 831           831  54 y/o Columbian speaking male with HTN, HL wh...
# 846           846                                                 HL
# 907           907  54 y/o Spanish speaking male with HTN, HL pres...
# 923           923                                     Hyperlipidemia
# 938           938  HPI:\tPatient is a 54- year old male w/pancrea...
# 1004         1004  PMH: S/p mechanical aortic valve replacement, ...
# 1043         1043     55 y/o Columbian male with a history of HTN...
# 1101         1101                                    Hyperlipidemia.
# 1147         1147     55 y/o Columbian male with a history of HTN...
# 1220         1220           (1)  Angina/hypertension/hyperlipidemia.
# 1266         1266                              Hypercholesterolemia.
# 1371         1371                        Hyperlipidemia, on Lipitor.
# ...           ...                                                ...
# 23858       23858  HPI: This is a 72-year-old right-handed woman ...
# 23872       23872                              Elevated cholesterol.
# 23955       23955  75-year-old woman with a history of hypertensi...
# 23969       23969                              Elevated cholesterol.
# 24087       24087  L stent 12/19Goiter  : multinodular, USG 2115A...
# 24091       24091  Hyperlipidemia - Taking gemfibrozil c good eff...
# 24113       24113  history of hypertension, hypercholesterolemia,...
# 24126       24126  PAST MEDICAL HISTORY:  Hypertension, hyperchol...
# 24188       24188  hypercholesterolemia presents to the emergency...
# 24203       24203  PAST MEDICAL HISTORY:  As noted above, hyperch...
# 24268       24268  HISTORY OF PRESENT ILLNESS:  Ms. Uhrich is a 7...
# 24275       24275  PAST MEDICAL HISTORY:  Notable for hypertensio...
# 24293       24293  In summary, Karson Uhrich is a 73-year-old wom...
# 24317       24317  Medical issues include osteopenia, hyperlipide...
# 24371       24371  Results05/03/2092 NA 139,  K 4.1,  CL 101,  CO...
# 24382       24382                                     Hyperlipidemia
# 24400       24400                                     Hyperlipidemia
# 24550       24550                                       LDL was 125.
# 24560       24560                              Elevated cholesterol.
# 24605       24605     Her LDL is 116 ono 2/87 and has DM, goal <100.
# 24741       24741                                     Hyperlipidemia
# 24814       24814  ###DYSLIPIDEMIA &#8211; simvastatin 20 mg dail...
# 24839       24839                       Elevated lipids - on statin
# 24886       24886                                                 HL
# 24956       24956                               Cholesterol was 315.
# 25026       25026                                       cholesterol.
# 25058       25058                                    Hyperlipidemia
# 25102       25102                HL;  check  cho profile on lipitor.
# 25121       25121                                    Hyperlipidemia
# 25262       25262  Impression: 89 year old male with past medical...
#
#             label        file    Class0    Class1    Class2    Class3  \
# 18     before DCT  110-03.xml  0.003151  0.017987  0.032193  0.946669
# 104     after DCT  110-04.xml  0.003151  0.017987  0.032193  0.946669
# 185     after DCT  112-02.xml  0.012428  0.324499  0.657111  0.005962
# 227    before DCT  112-03.xml  0.012428  0.324499  0.657111  0.005962
# 265    during DCT  112-04.xml  0.000782  0.001913  0.002474  0.994831
# 310     after DCT  114-03.xml  0.000795  0.406887  0.589512  0.002807
# 357    during DCT  114-04.xml  0.000779  0.001524  0.002448  0.995250
# 376    during DCT  114-04.xml  0.001389  0.000462  0.004218  0.993931
# 430    during DCT  114-04.xml  0.000716  0.001242  0.002449  0.995593
# 496         Other  115-04.xml  0.001924  0.000457  0.004667  0.992953
# 497    during DCT  115-04.xml  0.001349  0.005060  0.009838  0.983753
# 523         Other  115-04.xml  0.002071  0.009051  0.016796  0.972082
# 525    during DCT  115-04.xml  0.003151  0.017987  0.032193  0.946669
# 531         Other  115-04.xml  0.036477  0.040590  0.014822  0.908111
# 539         Other  115-04.xml  0.020691  0.000414  0.003545  0.975349
# 709    during DCT  117-02.xml  0.000663  0.000843  0.003537  0.994956
# 751    before DCT  117-02.xml  0.001740  0.000339  0.007734  0.990186
# 791    before DCT  117-02.xml  0.001270  0.000533  0.005125  0.993072
# 831    during DCT  118-01.xml  0.001639  0.000672  0.996231  0.001458
# 846    during DCT  118-01.xml  0.000364  0.000767  0.996599  0.002270
# 907    during DCT  118-01.xml  0.000618  0.000786  0.997278  0.001317
# 923    during DCT  118-01.xml  0.003151  0.017987  0.032193  0.946669
# 938         Other  118-02.xml  0.000951  0.987294  0.007985  0.003770
# 1004    after DCT  118-04.xml  0.002881  0.001472  0.005979  0.989668
# 1043   before DCT  118-05.xml  0.000364  0.000942  0.997319  0.001375
# 1101   during DCT  118-05.xml  0.000915  0.002056  0.004777  0.992252
# 1147   before DCT  118-05.xml  0.000354  0.000977  0.997311  0.001358
# 1220    after DCT  119-02.xml  0.000261  0.910047  0.088225  0.001467
# 1266   during DCT  130-01.xml  0.000689  0.000878  0.004228  0.994205
# 1371   during DCT  130-03.xml  0.000788  0.002638  0.004331  0.992243
# ...           ...         ...       ...       ...       ...       ...
# 23858  before DCT  380-02.xml  0.001184  0.000589  0.003357  0.994870
# 23872  before DCT  380-02.xml  0.000526  0.998068  0.000945  0.000461
# 23955  before DCT  380-03.xml  0.002176  0.000669  0.005081  0.992074
# 23969  before DCT  380-03.xml  0.000526  0.998068  0.000945  0.000461
# 24087  before DCT  383-05.xml  0.000415  0.009442  0.987801  0.002342
# 24091  before DCT  383-05.xml  0.000788  0.001114  0.003157  0.994940
# 24113  during DCT  384-01.xml  0.000655  0.000514  0.003885  0.994946
# 24126  during DCT  384-01.xml  0.001220  0.000524  0.004611  0.993645
# 24188  during DCT  384-02.xml  0.002239  0.000494  0.010023  0.987243
# 24203  during DCT  384-02.xml  0.000884  0.000445  0.004011  0.994660
# 24268  during DCT  384-03.xml  0.000902  0.001825  0.002755  0.994518
# 24275  before DCT  384-03.xml  0.000858  0.000538  0.003025  0.995579
# 24293  during DCT  384-03.xml  0.000939  0.000925  0.002637  0.995499
# 24317   after DCT  384-04.xml  0.000503  0.998544  0.000550  0.000403
# 24371       Other  384-04.xml  0.001791  0.001055  0.002025  0.995129
# 24382  during DCT  385-05.xml  0.003151  0.017987  0.032193  0.946669
# 24400  during DCT  385-05.xml  0.003151  0.017987  0.032193  0.946669
# 24550  before DCT  386-02.xml  0.001117  0.000662  0.995884  0.002338
# 24560       Other  386-02.xml  0.000526  0.998068  0.000945  0.000461
# 24605  before DCT  386-03.xml  0.000775  0.000803  0.997009  0.001414
# 24741  during DCT  387-02.xml  0.003151  0.017987  0.032193  0.946669
# 24814  before DCT  387-02.xml  0.000706  0.001451  0.002757  0.995086
# 24839  before DCT  387-03.xml  0.002212  0.994309  0.003033  0.000446
# 24886  before DCT  387-04.xml  0.000364  0.000767  0.996599  0.002270
# 24956  before DCT  388-03.xml  0.001146  0.000608  0.995709  0.002536
# 25026       Other  388-03.xml  0.000591  0.000834  0.992336  0.006239
# 25058  during DCT  388-04.xml  0.003151  0.017987  0.032193  0.946669
# 25102  during DCT  388-04.xml  0.014010  0.000913  0.392496  0.592581
# 25121  before DCT  388-05.xml  0.003151  0.017987  0.032193  0.946669
# 25262  before DCT  389-04.xml  0.000242  0.022669  0.975449  0.001640
#
#       predClass   predLabel
# 18       Class3  during DCT
# 104      Class3  during DCT
# 185      Class2  before DCT
# 227      Class2  before DCT
# 265      Class3  during DCT
# 310      Class2  before DCT
# 357      Class3  during DCT
# 376      Class3  during DCT
# 430      Class3  during DCT
# 496      Class3  during DCT
# 497      Class3  during DCT
# 523      Class3  during DCT
# 525      Class3  during DCT
# 531      Class3  during DCT
# 539      Class3  during DCT
# 709      Class3  during DCT
# 751      Class3  during DCT
# 791      Class3  during DCT
# 831      Class2  before DCT
# 846      Class2  before DCT
# 907      Class2  before DCT
# 923      Class3  during DCT
# 938      Class1   after DCT
# 1004     Class3  during DCT
# 1043     Class2  before DCT
# 1101     Class3  during DCT
# 1147     Class2  before DCT
# 1220     Class1   after DCT
# 1266     Class3  during DCT
# 1371     Class3  during DCT
# ...         ...         ...
# 23858    Class3  during DCT
# 23872    Class1   after DCT
# 23955    Class3  during DCT
# 23969    Class1   after DCT
# 24087    Class2  before DCT
# 24091    Class3  during DCT
# 24113    Class3  during DCT
# 24126    Class3  during DCT
# 24188    Class3  during DCT
# 24203    Class3  during DCT
# 24268    Class3  during DCT
# 24275    Class3  during DCT
# 24293    Class3  during DCT
# 24317    Class1   after DCT
# 24371    Class3  during DCT
# 24382    Class3  during DCT
# 24400    Class3  during DCT
# 24550    Class2  before DCT
# 24560    Class1   after DCT
# 24605    Class2  before DCT
# 24741    Class3  during DCT
# 24814    Class3  during DCT
# 24839    Class1   after DCT
# 24886    Class2  before DCT
# 24956    Class2  before DCT
# 25026    Class2  before DCT
# 25058    Class3  during DCT
# 25102    Class3  during DCT
# 25121    Class3  during DCT
# 25262    Class2  before DCT
#
# [398 rows x 10 columns]

# %%
HT_test_labels = HT_combined['label']
HT_pred_labels = HT_combined['predLabel']

#print(type(HT_test_labels))

# %%
accuracy_score(HT_test_labels, HT_pred_labels)
# Out:
# 0.990664926229184

# %%
print(classification_report(HT_pred_labels, HT_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       1.00      1.00      1.00     24883
#    after DCT       0.30      0.21      0.24        73
#   before DCT       0.39      0.49      0.43       123
#   during DCT       0.78      0.68      0.73       202
#
#    micro avg       0.99      0.99      0.99     25281
#    macro avg       0.62      0.59      0.60     25281
# weighted avg       0.99      0.99      0.99     25281

# %%
unique_label = np.unique(HT_test_labels)
print(pd.DataFrame(confusion_matrix(HT_test_labels, HT_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#                  pred:Other  pred:after DCT  pred:before DCT  pred:during DCT
# true:Other            24832              25               22               20
# true:after DCT           13              15               15                7
# true:before DCT          31              26               60               37
# true:during DCT           7               7               26              138

# %%
HI_combined[HI_combined['label'] =='high LDL']
# Out:
#        sentenceId                                           sentence  \
# 1641         1641                      181/39/112 WITH TG 149 11/85.
# 1642         1642                   194/42/123/4.6 WITH TG 147 7/86.
# 1643         1643                              12/88 188/42/118/4.5.
# 2825         2825                 Cholesterol-LDL   05/15/2090 165
# 3759         3759  Please see prior notes for full lipid analysis...
# 3891         3891                                            LDL 138
# 4543         4543  I restarted her on lipitor 20 mg po qd, given ...
# 4753         4753  and LDL from 09/15/83 was 154 with a total cho...
# 6186         6186  However, cholesterol now of 186, HDL 46, LDL 105.
# 6994         6994  11/95 TC 199, HDL 42, LDL 122, TG 171, and sim...
# 11443       11443  Lipid profile showed Cholesterol 210, Trig 59,...
# 11557       11557  His lipid panel from his hospitalization revea...
# 11875       11875                    Cholesterol-LDL 05/24/2095 101
# 12294       12294            PE:  WDWN BF NAD  Wt 135 lbs  BP 100/64
# 12304       12304  Throughout her hospitalization she lost a lot ...
# 12309       12309                            Cholesterol 225/68/135.
# 14258       14258  cholesterol of 229, triglyceride of 68, HDL 51...
# 15354       15354                 Cholesterol-LDL   07/17/2069 104
# 15458       15458     On 06/18/2070, total cholesterol 168, trigl...
# 15525       15525  Hyperlipidemia: 8/72 chol 169, Tgl 67, hdl 37,...
# 18743       18743  Fasting lipid analysis one year ago showed tot...
# 18932       18932  Fasting lipid analysis 18 months ago showed to...
# 19000       19000  Fasting lipid analysis 2 weeks ago showed tota...
# 19059       19059                                    and LDL of 110.
# 19167       19167                                     Last dLDL 108.
# 19269       19269                         LDL from last May was 164.
# 19410       19410                              Last LDL  134 on 6/28
# 21627       21627  -increased lipitor to 20 (patient's Chol 179 a...
# 22780       22780   His lipid profile from 4/71 showed a LDL of 103.
# 22847       22847   His lipid profile from 4/71 showed a LDL of 103.
# 23623       23623      Calculated LDL         161*  50-160 mg/dL ...
# 24550       24550                                       LDL was 125.
# 24605       24605     Her LDL is 116 ono 2/87 and has DM, goal <100.
#
#           label        file    Class0    Class1    Class2    Class3 predClass  \
# 1641   high LDL  131-01.xml  0.999955  0.000015  0.000008  0.000022    Class0
# 1642   high LDL  131-01.xml  0.999955  0.000014  0.000009  0.000022    Class0
# 1643   high LDL  131-01.xml  0.999956  0.000015  0.000009  0.000020    Class0
# 2825   high LDL  134-03.xml  0.000151  0.999499  0.000215  0.000135    Class1
# 3759   high LDL  138-03.xml  0.002036  0.997454  0.000256  0.000255    Class1
# 3891   high LDL  139-02.xml  0.000178  0.999498  0.000180  0.000145    Class1
# 4543   high LDL  162-04.xml  0.999865  0.000028  0.000017  0.000090    Class0
# 4753   high LDL  163-03.xml  0.000268  0.999434  0.000148  0.000150    Class1
# 6186   high LDL  169-01.xml  0.000139  0.999488  0.000249  0.000124    Class1
# 6994   high LDL  193-05.xml  0.999933  0.000018  0.000010  0.000038    Class0
# 11443  high LDL  211-01.xml  0.389903  0.603864  0.002872  0.003361    Class1
# 11557  high LDL  211-02.xml  0.999395  0.000085  0.000032  0.000489    Class0
# 11875  high LDL  214-01.xml  0.000856  0.998807  0.000100  0.000238    Class1
# 12294  high LDL  216-03.xml  0.999954  0.000014  0.000009  0.000023    Class0
# 12304  high LDL  216-03.xml  0.999954  0.000016  0.000009  0.000021    Class0
# 12309  high LDL  216-03.xml  0.999896  0.000022  0.000019  0.000063    Class0
# 14258  high LDL  236-02.xml  0.000184  0.999471  0.000214  0.000130    Class1
# 15354  high LDL  260-02.xml  0.000205  0.999486  0.000164  0.000144    Class1
# 15458  high LDL  260-03.xml  0.999724  0.000074  0.000015  0.000187    Class0
# 15525  high LDL  260-04.xml  0.002247  0.000209  0.000207  0.997337    Class3
# 18743  high LDL  318-01.xml  0.999731  0.000083  0.000051  0.000135    Class0
# 18932  high LDL  318-03.xml  0.999852  0.000041  0.000028  0.000080    Class0
# 19000  high LDL  318-04.xml  0.999833  0.000042  0.000031  0.000094    Class0
# 19059  high LDL  319-01.xml  0.000134  0.999485  0.000251  0.000130    Class1
# 19167  high LDL  319-03.xml  0.999955  0.000015  0.000009  0.000021    Class0
# 19269  high LDL  340-03.xml  0.000165  0.999499  0.000198  0.000138    Class1
# 19410  high LDL  342-04.xml  0.999934  0.000022  0.000009  0.000035    Class0
# 21627  high LDL  372-02.xml  0.001590  0.997898  0.000238  0.000273    Class1
# 22780  high LDL  376-01.xml  0.155540  0.842182  0.000571  0.001708    Class1
# 22847  high LDL  376-02.xml  0.155540  0.842182  0.000571  0.001708    Class1
# 23623  high LDL  379-05.xml  0.999948  0.000016  0.000008  0.000029    Class0
# 24550  high LDL  386-02.xml  0.000162  0.999504  0.000197  0.000138    Class1
# 24605  high LDL  386-03.xml  0.000777  0.998897  0.000108  0.000218    Class1
#
#       predLabel
# 1641      Other
# 1642      Other
# 1643      Other
# 2825   high LDL
# 3759   high LDL
# 3891   high LDL
# 4543      Other
# 4753   high LDL
# 6186   high LDL
# 6994      Other
# 11443  high LDL
# 11557     Other
# 11875  high LDL
# 12294     Other
# 12304     Other
# 12309     Other
# 14258  high LDL
# 15354  high LDL
# 15458     Other
# 15525   mention
# 18743     Other
# 18932     Other
# 19000     Other
# 19059  high LDL
# 19167     Other
# 19269  high LDL
# 19410     Other
# 21627  high LDL
# 22780  high LDL
# 22847  high LDL
# 23623     Other
# 24550  high LDL
# 24605  high LDL

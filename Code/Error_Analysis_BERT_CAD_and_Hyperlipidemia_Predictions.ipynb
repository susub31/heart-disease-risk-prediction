# %% [markdown]
# ## Error Analysis for CAD and Hyperlipidemia Tag Predictions (BERT)

# %%
import os
import string
import random
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
import numpy as np

# %% [markdown]
# ### Test LABELS for TOKENS in TEST Dataset against BERT Outputs
#
# BERT Classifier has returned results for the tokens passed in 'test.tsv' file.  The returned values are probabilities, that need to be converted into equivalent class labels based on majority class.  Then, the class label should be compared against the actual label from the code above to extract the IO-Coding from the xml files.  This is a brute-force approach or a manual way of verifying the validity of the predictions

# %% [markdown]
# Read in results from BERT Predicitons to the above dataset
# The above dataset is derived from IO-Coding applied as done on the training set. This is what should be based on the annotation process. Nowe, we have to read in the predictions from bert, which is a set of class probabilities across all 3 classes and we have to merget that with the above dataset for comparison and error analysis.

# %% [markdown]
# ### Data File Names

# %% [markdown]
# * Test files with Labels and Filenames : /data_for_bert_sent/test_files_with_labels/*_testfile.csv
# * Bert label mapping /data_for_bert_sent/test_files_with_labels/*_labelmapping.csv
# * BERT evaluation /data_for_bert_sent/BERT_run_results/*_eval_results.txt

# %%
print(os.path.dirname(os.path.abspath('__file__')))
# Out:
# C:\Users\Kalyan\Documents\Anu\W266 - NLP\Final Project\lheart-disease-risk-prediction\Code

# %% [markdown]
# ### CAD Indicator

# %%
# read in the test files with labels

CI_test = pd.read_csv("data_for_bert_sent/test_files_with_labels/cad_ind_testfile.csv")

# %%
CI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
CI_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...   test
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Hypertension model and specify columns as the actual file has no header
bert_CI_results = pd.read_csv("data_for_bert_sent/BERT_run_results/sentence_based_output_data_cad_output_results_test_results.tsv", sep='\t')
                               
bert_CI_results.columns=["Class0", "Class1", "Class2", "Class3", "Class4"]

# %%
bert_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4
# 0  0.081534  0.253442  0.007367  0.403286  0.254370
# 1  0.135596  0.200983  0.007128  0.403985  0.252308
# 2  0.146809  0.201183  0.007665  0.401277  0.243066
# 3  0.059850  0.297005  0.007313  0.415374  0.220459
# 4  0.073586  0.400443  0.007947  0.301205  0.216819

# %%
bert_CI_results['predClass'] = bert_CI_results.idxmax(axis=1)

# %%
bert_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass
# 0  0.081534  0.253442  0.007367  0.403286  0.254370    Class3
# 1  0.135596  0.200983  0.007128  0.403985  0.252308    Class3
# 2  0.146809  0.201183  0.007665  0.401277  0.243066    Class3
# 3  0.059850  0.297005  0.007313  0.415374  0.220459    Class3
# 4  0.073586  0.400443  0.007947  0.301205  0.216819    Class1

# %%
bert_CI_results['predClass'].value_counts()
# Out:
# Class0    20778
# Class2      357
# Class1      253
# Class3       25
# Name: predClass, dtype: int64

# %%
def CI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'event'
    elif (classlabel=='Class2'):
        return 'mention'
    elif (classlabel=='Class3'):
        return 'symptom'
    elif (classlabel=='Class4'):
        return 'test'
    else:
        return 'Other'

# %%
bert_CI_results['predLabel'] = bert_CI_results['predClass'].apply(CI_set_labels)

bert_CI_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass predLabel
# 0  0.081534  0.253442  0.007367  0.403286  0.254370    Class3   symptom
# 1  0.135596  0.200983  0.007128  0.403985  0.252308    Class3   symptom
# 2  0.146809  0.201183  0.007665  0.401277  0.243066    Class3   symptom
# 3  0.059850  0.297005  0.007313  0.415374  0.220459    Class3   symptom
# 4  0.073586  0.400443  0.007947  0.301205  0.216819    Class1     event
# 5  0.047652  0.450680  0.007981  0.280313  0.213373    Class1     event
# 6  0.142763  0.186687  0.007067  0.455583  0.207900    Class3   symptom
# 7  0.162023  0.168344  0.006922  0.455268  0.207443    Class3   symptom
# 8  0.044175  0.469306  0.008372  0.272334  0.205813    Class1     event
# 9  0.081133  0.295469  0.006694  0.413121  0.203584    Class3   symptom

# %%
# validating the counts by label
bert_CI_results['predLabel'].value_counts()
# Out:
# Other      20778
# mention      357
# event        253
# symptom       25
# Name: predLabel, dtype: int64

# %%
CI_combined = pd.concat([CI_test, bert_CI_results], axis=1)

# %%
CI_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.081534  0.253442
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.135596  0.200983
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.146809  0.201183
# 3           3             MR:\t8249813  Other  110-03.xml  0.059850  0.297005
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.073586  0.400443
#
#      Class2    Class3    Class4 predClass predLabel
# 0  0.007367  0.403286  0.254370    Class3   symptom
# 1  0.007128  0.403985  0.252308    Class3   symptom
# 2  0.007665  0.401277  0.243066    Class3   symptom
# 3  0.007313  0.415374  0.220459    Class3   symptom
# 4  0.007947  0.301205  0.216819    Class1     event

# %%
CI_combined[CI_combined['predLabel']!='Other']
# Out:
#      sentenceId                                           sentence  label  \
# 0             0                            Record date: 2080-02-18  Other
# 1             1                             SDU JAR Admission Note  Other
# 2             2                            Name: \t Yosef Villegas  Other
# 3             3                                       MR:\t8249813  Other
# 4             4                                    DOA:  \t2/17/80  Other
# 5             5                                PCP:  Gilbert Perez  Other
# 6             6                                  Attending: YBARRA  Other
# 7             7                                         CODE: FULL  Other
# 8             8  HPI:  70 yo M with NIDDM admitted for cath aft...   test
# 9             9  Pt has had increasing CP and SOB on exertion f...  Other
# 10           10  Pt was scheduled for stress MIBI today to eval...  Other
# 11           11  MIBI was reportedly stopped 2/2 to chest pain,...  Other
# 12           12  MIBI was read as positive for moderate to seve...   test
# 13           13                                              PMH:   Other
# 14           14                 Seronegative Rheumatoid Arthritis   Other
# 15           15                                                HTN  Other
# 16           16                           Right Carotid Artery Dz   Other
# 17           17                                           Obesity   Other
# 19           19                           Diabetes mellitus type 2  Other
# 21           21        Acetylsalicylic Acid (Aspirin)  PO 81 MG QD  Other
# 22           22                        Xanax (Alprazolam)  PO  BID  Other
# 24           24                     Enalapril Maleate  PO 10 MG QD  Other
# 25           25                 Hctz (Hydrochlorothiazide)  PO  QD  Other
# 26           26                           Metformin  PO 850 MG BID  Other
# 27           27                                    Allergies: NKDA  Other
# 28           28  Social History:  Smokes 2 packs per month, dri...  Other
# 29           29                                          Exam:  \t  Other
# 30           30  VS: T: 98.1  HR: 59  BP: 158/72  RR: 20  Sat: ...  Other
# 32           32  HEENT: Pupils equal, round, and reactive to li...  Other
# 33           33  Pulmonary: Clear to auscultation bilaterally, ...  Other
# ..          ...                                                ...    ...
# 938         938                                  Lipitor 40 mg QD.  Other
# 939         939                                    Allergies: NKDA  Other
# 940         940                                    Physical Exam:   Other
# 941         941  CV: RRR (+) S1/S2, 2+ radial pulses, audible m...  Other
# 942         942                                         Pulm: CTAB  Other
# 943         943                             Abdomen: Abdomen soft.  Other
# 944         944                        He is completely nontender.  Other
# 945         945                                     Ext: No e/c/c.  Other
# 946         946                                           Imaging:  Other
# 947         947                                                 1.  Other
# 948         948  CXR: Bilateral pleural effusions, no free air ...  Other
# 949         949                                                 2.  Other
# 950         950  CT scan from OSH of abdomen: reveals phlegmon ...  Other
# 951         951                                                 3.  Other
# 952         952  CT scan from 10/10/17 at PNC: Overall decrease...  Other
# 953         953                                                 4.  Other
# 954         954  CT from 1/02/18: No significant change in hypo...  Other
# 955         955                                    Cholelithiasis.  Other
# 956         956             Diverticulosis without diverticulitis.  Other
# 957         957                           Assessment/Plan: 54 y.o.  Other
# 958         958  male with post-ERCP pancreatitis which is not ...  Other
# 959         959                               -Cardiology consult.  Other
# 960         960                       -Anesthesia pre-op clearance  Other
# 961         961                                        -Home meds.  Other
# 962         962                                      -d/c Coumadin  Other
# 963         963  -Start heparin drip after stat labs (check PTT...  Other
# 964         964                                     -Regular diet.  Other
# 968         968                            Record date: 2118-04-15  Other
# 969         969                                       \tCARDIOLOGY  Other
# 970         970                                                 \t  Other
#
#            file    Class0    Class1    Class2    Class3    Class4 predClass  \
# 0    110-03.xml  0.081534  0.253442  0.007367  0.403286  0.254370    Class3
# 1    110-03.xml  0.135596  0.200983  0.007128  0.403985  0.252308    Class3
# 2    110-03.xml  0.146809  0.201183  0.007665  0.401277  0.243066    Class3
# 3    110-03.xml  0.059850  0.297005  0.007313  0.415374  0.220459    Class3
# 4    110-03.xml  0.073586  0.400443  0.007947  0.301205  0.216819    Class1
# 5    110-03.xml  0.047652  0.450680  0.007981  0.280313  0.213373    Class1
# 6    110-03.xml  0.142763  0.186687  0.007067  0.455583  0.207900    Class3
# 7    110-03.xml  0.162023  0.168344  0.006922  0.455268  0.207443    Class3
# 8    110-03.xml  0.044175  0.469306  0.008372  0.272334  0.205813    Class1
# 9    110-03.xml  0.081133  0.295469  0.006694  0.413121  0.203584    Class3
# 10   110-03.xml  0.100900  0.275819  0.007374  0.412514  0.203393    Class3
# 11   110-03.xml  0.292192  0.152631  0.007213  0.346079  0.201885    Class3
# 12   110-03.xml  0.181103  0.172076  0.007049  0.442233  0.197539    Class3
# 13   110-03.xml  0.172437  0.159680  0.007034  0.463428  0.197421    Class3
# 14   110-03.xml  0.199835  0.147492  0.006626  0.460586  0.185461    Class3
# 15   110-03.xml  0.238982  0.148012  0.006932  0.424761  0.181314    Class3
# 16   110-03.xml  0.146382  0.250116  0.007241  0.415383  0.180877    Class3
# 17   110-03.xml  0.146382  0.250116  0.007241  0.415383  0.180877    Class3
# 19   110-03.xml  0.053208  0.522010  0.007427  0.240162  0.177194    Class1
# 21   110-03.xml  0.115595  0.478966  0.009421  0.225700  0.170318    Class1
# 22   110-03.xml  0.115595  0.478966  0.009421  0.225700  0.170318    Class1
# 24   110-03.xml  0.313588  0.116178  0.006420  0.394553  0.169261    Class3
# 25   110-03.xml  0.174191  0.283735  0.009474  0.369594  0.163006    Class3
# 26   110-03.xml  0.162223  0.382737  0.008759  0.285352  0.160929    Class1
# 27   110-03.xml  0.338000  0.109151  0.006283  0.387014  0.159553    Class3
# 28   110-03.xml  0.342085  0.110182  0.006168  0.387322  0.154243    Class3
# 29   110-03.xml  0.269225  0.214641  0.008682  0.354616  0.152835    Class3
# 30   110-03.xml  0.339073  0.105624  0.006549  0.397207  0.151547    Class3
# 32   110-03.xml  0.047945  0.602295  0.008560  0.192774  0.148425    Class1
# 33   110-03.xml  0.312787  0.197371  0.009254  0.334579  0.146010    Class3
# ..          ...       ...       ...       ...       ...       ...       ...
# 938  118-04.xml  0.006795  0.003294  0.987618  0.000953  0.001340    Class2
# 939  118-04.xml  0.006795  0.003294  0.987618  0.000953  0.001340    Class2
# 940  118-04.xml  0.005899  0.003183  0.988631  0.000947  0.001340    Class2
# 941  118-04.xml  0.007013  0.003162  0.987535  0.000951  0.001340    Class2
# 942  118-04.xml  0.007395  0.003127  0.987175  0.000964  0.001340    Class2
# 943  118-04.xml  0.006787  0.003200  0.987719  0.000955  0.001340    Class2
# 944  118-04.xml  0.006110  0.003205  0.988393  0.000952  0.001339    Class2
# 945  118-04.xml  0.006411  0.003213  0.988093  0.000945  0.001339    Class2
# 946  118-04.xml  0.006431  0.003249  0.988031  0.000950  0.001339    Class2
# 947  118-04.xml  0.005609  0.003251  0.988856  0.000945  0.001339    Class2
# 948  118-04.xml  0.007146  0.003151  0.987413  0.000952  0.001339    Class2
# 949  118-04.xml  0.007134  0.003247  0.987337  0.000944  0.001338    Class2
# 950  118-04.xml  0.007123  0.003040  0.987550  0.000949  0.001337    Class2
# 951  118-04.xml  0.006616  0.004877  0.986238  0.000931  0.001337    Class2
# 952  118-04.xml  0.006616  0.004877  0.986238  0.000931  0.001337    Class2
# 953  118-04.xml  0.006547  0.003207  0.987951  0.000957  0.001337    Class2
# 954  118-04.xml  0.006027  0.003245  0.988451  0.000942  0.001336    Class2
# 955  118-04.xml  0.006339  0.003109  0.988259  0.000958  0.001336    Class2
# 956  118-04.xml  0.007531  0.003090  0.987093  0.000951  0.001336    Class2
# 957  118-04.xml  0.006181  0.003095  0.988444  0.000945  0.001335    Class2
# 958  118-04.xml  0.007136  0.003390  0.987208  0.000933  0.001334    Class2
# 959  118-04.xml  0.004874  0.003432  0.989431  0.000929  0.001334    Class2
# 960  118-04.xml  0.007691  0.003192  0.986827  0.000957  0.001333    Class2
# 961  118-04.xml  0.006001  0.003369  0.988354  0.000943  0.001333    Class2
# 962  118-04.xml  0.005792  0.003742  0.988206  0.000928  0.001332    Class2
# 963  118-04.xml  0.007022  0.003160  0.987544  0.000943  0.001331    Class2
# 964  118-04.xml  0.006953  0.003258  0.987522  0.000937  0.001330    Class2
# 968  118-05.xml  0.006660  0.003381  0.987703  0.000932  0.001323    Class2
# 969  118-05.xml  0.007072  0.003289  0.987381  0.000936  0.001323    Class2
# 970  118-05.xml  0.006312  0.003396  0.988031  0.000939  0.001323    Class2
#
#     predLabel
# 0     symptom
# 1     symptom
# 2     symptom
# 3     symptom
# 4       event
# 5       event
# 6     symptom
# 7     symptom
# 8       event
# 9     symptom
# 10    symptom
# 11    symptom
# 12    symptom
# 13    symptom
# 14    symptom
# 15    symptom
# 16    symptom
# 17    symptom
# 19      event
# 21      event
# 22      event
# 24    symptom
# 25    symptom
# 26      event
# 27    symptom
# 28    symptom
# 29    symptom
# 30    symptom
# 32      event
# 33    symptom
# ..        ...
# 938   mention
# 939   mention
# 940   mention
# 941   mention
# 942   mention
# 943   mention
# 944   mention
# 945   mention
# 946   mention
# 947   mention
# 948   mention
# 949   mention
# 950   mention
# 951   mention
# 952   mention
# 953   mention
# 954   mention
# 955   mention
# 956   mention
# 957   mention
# 958   mention
# 959   mention
# 960   mention
# 961   mention
# 962   mention
# 963   mention
# 964   mention
# 968   mention
# 969   mention
# 970   mention
#
# [635 rows x 11 columns]

# %%
CI_test_labels = CI_combined['label']
CI_pred_labels = CI_combined['predLabel']

#print(type(CI_test_labels))

# %%
accuracy_score(CI_test_labels, CI_pred_labels)
# Out:
# 0.9356932704431887

# %%
print(classification_report(CI_pred_labels, CI_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       0.97      0.96      0.97     20778
#        event       0.02      0.02      0.02       253
#      mention       0.00      0.00      0.00       357
#      symptom       0.00      0.00      0.00        25
#         test       0.00      0.00      0.00         0
#
#    micro avg       0.94      0.94      0.94     21413
#    macro avg       0.20      0.20      0.20     21413
# weighted avg       0.94      0.94      0.94     21413
# C:\Users\Kalyan\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
unique_label = np.unique(CI_test_labels)
print(pd.DataFrame(confusion_matrix(CI_test_labels, CI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#               pred:Other  pred:event  pred:mention  pred:symptom  pred:test
# true:Other         20030         238           350            24          0
# true:event           258           5             2             0          0
# true:mention         321           7             1             0          0
# true:symptom         104           0             4             0          0
# true:test             65           3             0             1          0

# %% [markdown]
# ### Hyperlipidemia Indicator

# %%
# read in the test files with labels

HI_test = pd.read_csv("data_for_bert_sent/test_files_with_labels/hyperlipidemia_ind_testfile.csv")

# %%
HI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
HI_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...  Other
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Hyperlipidemia model and specify columns as the actual file has no header
bert_HI_results = pd.read_csv("data_for_bert_sent/BERT_run_results/hyperlipidemia_test_results.tsv", sep='\t',header=None)
 
bert_HI_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2    Class3
# 0  0.999941  0.000024  0.000011  0.000024
# 1  0.999939  0.000024  0.000011  0.000026
# 2  0.999814  0.000045  0.000022  0.000119
# 3  0.999750  0.000065  0.000029  0.000156
# 4  0.999768  0.000061  0.000027  0.000144

# %%
bert_HI_results['predClass'] = bert_HI_results.idxmax(axis=1)

# %%
bert_HI_results.head()
# Out:
#      Class0    Class1    Class2    Class3 predClass
# 0  0.999941  0.000024  0.000011  0.000024    Class0
# 1  0.999939  0.000024  0.000011  0.000026    Class0
# 2  0.999814  0.000045  0.000022  0.000119    Class0
# 3  0.999750  0.000065  0.000029  0.000156    Class0
# 4  0.999768  0.000061  0.000027  0.000144    Class0

# %%
bert_HI_results['predClass'].value_counts()
# Out:
# Class0    24943
# Class3      338
# Name: predClass, dtype: int64

# %%
def HI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'high LDL'
    elif (classlabel=='Class2'):
        return 'high chol.'
    elif (classlabel=='Class3'):
        return 'mention'
    else:
        return 'Other'

# %%
bert_HI_results['predLabel'] = bert_HI_results['predClass'].apply(HI_set_labels)

bert_HI_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3 predClass predLabel
# 0  0.999941  0.000024  0.000011  0.000024    Class0     Other
# 1  0.999939  0.000024  0.000011  0.000026    Class0     Other
# 2  0.999814  0.000045  0.000022  0.000119    Class0     Other
# 3  0.999750  0.000065  0.000029  0.000156    Class0     Other
# 4  0.999768  0.000061  0.000027  0.000144    Class0     Other
# 5  0.999943  0.000022  0.000010  0.000025    Class0     Other
# 6  0.999944  0.000020  0.000010  0.000026    Class0     Other
# 7  0.999944  0.000020  0.000009  0.000026    Class0     Other
# 8  0.999938  0.000026  0.000010  0.000026    Class0     Other
# 9  0.999939  0.000024  0.000010  0.000026    Class0     Other

# %%
# validating the counts by label
bert_HI_results['predLabel'].value_counts()
# Out:
# Other      24943
# mention      338
# Name: predLabel, dtype: int64

# %%
HI_combined = pd.concat([HI_test, bert_HI_results], axis=1)

# %%
HI_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999941  0.000024
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999939  0.000024
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999814  0.000045
# 3           3             MR:\t8249813  Other  110-03.xml  0.999750  0.000065
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.999768  0.000061
#
#      Class2    Class3 predClass predLabel
# 0  0.000011  0.000024    Class0     Other
# 1  0.000011  0.000026    Class0     Other
# 2  0.000022  0.000119    Class0     Other
# 3  0.000029  0.000156    Class0     Other
# 4  0.000027  0.000144    Class0     Other

# %%
HI_combined[HI_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence    label  \
# 18             18                                    Hyperlipidemia   mention
# 104           104                                     hyperlipidemia  mention
# 185           185  His past medical history is significant for hy...  mention
# 227           227  His past medical history is significant for hy...  mention
# 265           265  He is a 54-year-old man with obesity, dyslipid...  mention
# 310           310                                  High cholesterol.  mention
# 357           357              Mr. Slater is an 83 yo w/ h/o bull...  mention
# 376           376                &#183;         Hypercholesterolemia  mention
# 430           430  : Mr. Slater is an 83 yo w/ h/o bullous pemphi...  mention
# 497           497                              Hyperlipidemia MAJOR   mention
# 525           525                                     Hyperlipidemia  mention
# 709           709                               Hypercholesterolemia  mention
# 751           751  Cardiovascular: see HPI; hypertension; hyperch...  mention
# 791           791  71 year old female with a history of diabetes,...  mention
# 831           831  54 y/o Columbian speaking male with HTN, HL wh...  mention
# 846           846                                                 HL  mention
# 907           907  54 y/o Spanish speaking male with HTN, HL pres...  mention
# 923           923                                     Hyperlipidemia  mention
# 1004         1004  PMH: S/p mechanical aortic valve replacement, ...  mention
# 1043         1043     55 y/o Columbian male with a history of HTN...  mention
# 1101         1101                                    Hyperlipidemia.  mention
# 1147         1147     55 y/o Columbian male with a history of HTN...  mention
# 1220         1220           (1)  Angina/hypertension/hyperlipidemia.  mention
# 1266         1266                              Hypercholesterolemia.  mention
# 1371         1371                        Hyperlipidemia, on Lipitor.  mention
# 1438         1438                                              - HLD  mention
# 1523         1523  foot drop, anemia, sciatica, left thigh pain, ...  mention
# 1639         1639                 elevated serum cholesterol\t          Other
# 1814         1814                 elevated serum cholesterol          mention
# 1907         1907  His PMH includes hypertension, hyperlipidemia,...  mention
# ...           ...                                                ...      ...
# 23500       23500  Currently his major needs are to establish goo...    Other
# 23677       23677  hypercholesterolemia who was admitted to the N...  mention
# 23733       23733                                       cholesterol.    Other
# 23829       23829  blood pressure, diabetes, and hypercholesterol...    Other
# 23858       23858  HPI: This is a 72-year-old right-handed woman ...  mention
# 23872       23872                              Elevated cholesterol.  mention
# 23955       23955  75-year-old woman with a history of hypertensi...  mention
# 23969       23969                              Elevated cholesterol.  mention
# 24087       24087  L stent 12/19Goiter  : multinodular, USG 2115A...  mention
# 24091       24091  Hyperlipidemia - Taking gemfibrozil c good eff...  mention
# 24113       24113  history of hypertension, hypercholesterolemia,...  mention
# 24126       24126  PAST MEDICAL HISTORY:  Hypertension, hyperchol...  mention
# 24188       24188  hypercholesterolemia presents to the emergency...  mention
# 24203       24203  PAST MEDICAL HISTORY:  As noted above, hyperch...  mention
# 24268       24268  HISTORY OF PRESENT ILLNESS:  Ms. Uhrich is a 7...  mention
# 24275       24275  PAST MEDICAL HISTORY:  Notable for hypertensio...  mention
# 24293       24293  In summary, Karson Uhrich is a 73-year-old wom...  mention
# 24317       24317  Medical issues include osteopenia, hyperlipide...  mention
# 24382       24382                                     Hyperlipidemia  mention
# 24400       24400                                     Hyperlipidemia  mention
# 24560       24560                              Elevated cholesterol.    Other
# 24741       24741                                     Hyperlipidemia  mention
# 24814       24814  ###DYSLIPIDEMIA &#8211; simvastatin 20 mg dail...  mention
# 24839       24839                       Elevated lipids - on statin   mention
# 24886       24886                                                 HL  mention
# 25026       25026                                       cholesterol.    Other
# 25058       25058                                    Hyperlipidemia   mention
# 25102       25102                HL;  check  cho profile on lipitor.  mention
# 25121       25121                                    Hyperlipidemia   mention
# 25262       25262  Impression: 89 year old male with past medical...  mention
#
#              file    Class0    Class1    Class2    Class3 predClass predLabel
# 18     110-03.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 104    110-04.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 185    112-02.xml  0.005675  0.000727  0.000548  0.993050    Class3   mention
# 227    112-03.xml  0.005675  0.000727  0.000548  0.993050    Class3   mention
# 265    112-04.xml  0.005495  0.000734  0.000553  0.993219    Class3   mention
# 310    114-03.xml  0.007165  0.000818  0.000588  0.991429    Class3   mention
# 357    114-04.xml  0.005627  0.000726  0.000547  0.993100    Class3   mention
# 376    114-04.xml  0.005720  0.000727  0.000557  0.992996    Class3   mention
# 430    114-04.xml  0.005652  0.000726  0.000548  0.993074    Class3   mention
# 497    115-04.xml  0.005867  0.000740  0.000559  0.992834    Class3   mention
# 525    115-04.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 709    117-02.xml  0.005711  0.000726  0.000558  0.993005    Class3   mention
# 751    117-02.xml  0.005712  0.000718  0.000552  0.993017    Class3   mention
# 791    117-02.xml  0.005484  0.000731  0.000559  0.993227    Class3   mention
# 831    118-01.xml  0.008147  0.000812  0.000573  0.990469    Class3   mention
# 846    118-01.xml  0.006244  0.000733  0.000558  0.992465    Class3   mention
# 907    118-01.xml  0.007018  0.000803  0.000567  0.991612    Class3   mention
# 923    118-01.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 1004   118-04.xml  0.005564  0.000733  0.000555  0.993148    Class3   mention
# 1043   118-05.xml  0.005691  0.000727  0.000552  0.993029    Class3   mention
# 1101   118-05.xml  0.005852  0.000744  0.000561  0.992843    Class3   mention
# 1147   118-05.xml  0.005696  0.000727  0.000552  0.993025    Class3   mention
# 1220   119-02.xml  0.005751  0.000739  0.000555  0.992954    Class3   mention
# 1266   130-01.xml  0.005797  0.000731  0.000561  0.992910    Class3   mention
# 1371   130-03.xml  0.005900  0.000744  0.000557  0.992799    Class3   mention
# 1438   130-04.xml  0.006616  0.000761  0.000561  0.992061    Class3   mention
# 1523   130-05.xml  0.005681  0.000734  0.000555  0.993030    Class3   mention
# 1639   131-01.xml  0.012762  0.001450  0.000895  0.984893    Class3   mention
# 1814   131-02.xml  0.008308  0.000971  0.000652  0.990069    Class3   mention
# 1907   131-03.xml  0.005639  0.000745  0.000558  0.993058    Class3   mention
# ...           ...       ...       ...       ...       ...       ...       ...
# 23500  379-01.xml  0.005796  0.000711  0.000545  0.992948    Class3   mention
# 23677  380-01.xml  0.005825  0.000723  0.000556  0.992897    Class3   mention
# 23733  380-01.xml  0.051427  0.006844  0.003746  0.937984    Class3   mention
# 23829  380-01.xml  0.006121  0.000736  0.000560  0.992584    Class3   mention
# 23858  380-02.xml  0.005648  0.000720  0.000554  0.993078    Class3   mention
# 23872  380-02.xml  0.007333  0.000834  0.000595  0.991238    Class3   mention
# 23955  380-03.xml  0.005599  0.000724  0.000558  0.993118    Class3   mention
# 23969  380-03.xml  0.007333  0.000834  0.000595  0.991238    Class3   mention
# 24087  383-05.xml  0.006379  0.000728  0.000544  0.992348    Class3   mention
# 24091  383-05.xml  0.005801  0.000728  0.000552  0.992919    Class3   mention
# 24113  384-01.xml  0.005600  0.000734  0.000566  0.993099    Class3   mention
# 24126  384-01.xml  0.005450  0.000733  0.000559  0.993258    Class3   mention
# 24188  384-02.xml  0.005915  0.000721  0.000553  0.992811    Class3   mention
# 24203  384-02.xml  0.005510  0.000730  0.000557  0.993203    Class3   mention
# 24268  384-03.xml  0.005653  0.000719  0.000545  0.993083    Class3   mention
# 24275  384-03.xml  0.005495  0.000728  0.000555  0.993222    Class3   mention
# 24293  384-03.xml  0.005549  0.000722  0.000548  0.993181    Class3   mention
# 24317  384-04.xml  0.005489  0.000741  0.000555  0.993215    Class3   mention
# 24382  385-05.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 24400  385-05.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 24560  386-02.xml  0.007333  0.000834  0.000595  0.991238    Class3   mention
# 24741  387-02.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 24814  387-02.xml  0.013270  0.000891  0.000599  0.985239    Class3   mention
# 24839  387-03.xml  0.007598  0.000771  0.000574  0.991056    Class3   mention
# 24886  387-04.xml  0.006244  0.000733  0.000558  0.992465    Class3   mention
# 25026  388-03.xml  0.051427  0.006844  0.003746  0.937984    Class3   mention
# 25058  388-04.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 25102  388-04.xml  0.007111  0.000764  0.000555  0.991570    Class3   mention
# 25121  388-05.xml  0.005793  0.000736  0.000558  0.992913    Class3   mention
# 25262  389-04.xml  0.005588  0.000733  0.000555  0.993125    Class3   mention
#
# [338 rows x 10 columns]

# %%
HI_test_labels = HI_combined['label']
HI_pred_labels = HI_combined['predLabel']

#print(type(HI_test_labels))

# %%
accuracy_score(HI_test_labels, HI_pred_labels)
# Out:
# 0.9960049048692694

# %%
print(classification_report(HI_pred_labels, HI_test_labels))
# Out:
# C:\Users\Kalyan\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#               precision    recall  f1-score   support
#
#        Other       1.00      1.00      1.00     24943
#     high LDL       0.00      0.00      0.00         0
#   high chol.       0.00      0.00      0.00         0
#      mention       0.90      0.91      0.91       338
#
#    micro avg       1.00      1.00      1.00     25281
#    macro avg       0.48      0.48      0.48     25281
# weighted avg       1.00      1.00      1.00     25281

# %%
unique_label = np.unique(HI_test_labels)
print(pd.DataFrame(confusion_matrix(HI_test_labels, HI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#                  pred:Other  pred:high LDL  pred:high chol.  pred:mention
# true:Other            24871              0                0            28
# true:high LDL            30              0                0             1
# true:high chol.           9              0                0             0
# true:mention             33              0                0           309

# %%
HI_combined[HI_combined['label'] =='high LDL']
# Out:
#        sentenceId                                           sentence  \
# 1641         1641                      181/39/112 WITH TG 149 11/85.
# 1642         1642                   194/42/123/4.6 WITH TG 147 7/86.
# 1643         1643                              12/88 188/42/118/4.5.
# 2825         2825                 Cholesterol-LDL   05/15/2090 165
# 3759         3759  Please see prior notes for full lipid analysis...
# 3891         3891                                            LDL 138
# 4543         4543  I restarted her on lipitor 20 mg po qd, given ...
# 4753         4753  and LDL from 09/15/83 was 154 with a total cho...
# 6186         6186  However, cholesterol now of 186, HDL 46, LDL 105.
# 6994         6994  11/95 TC 199, HDL 42, LDL 122, TG 171, and sim...
# 11443       11443  Lipid profile showed Cholesterol 210, Trig 59,...
# 11875       11875                    Cholesterol-LDL 05/24/2095 101
# 12294       12294            PE:  WDWN BF NAD  Wt 135 lbs  BP 100/64
# 12304       12304  Throughout her hospitalization she lost a lot ...
# 12309       12309                            Cholesterol 225/68/135.
# 14258       14258  cholesterol of 229, triglyceride of 68, HDL 51...
# 15354       15354                 Cholesterol-LDL   07/17/2069 104
# 15458       15458     On 06/18/2070, total cholesterol 168, trigl...
# 15525       15525  Hyperlipidemia: 8/72 chol 169, Tgl 67, hdl 37,...
# 18743       18743  Fasting lipid analysis one year ago showed tot...
# 18932       18932  Fasting lipid analysis 18 months ago showed to...
# 19059       19059                                    and LDL of 110.
# 19167       19167                                     Last dLDL 108.
# 19269       19269                         LDL from last May was 164.
# 19410       19410                              Last LDL  134 on 6/28
# 21627       21627  -increased lipitor to 20 (patient's Chol 179 a...
# 22780       22780   His lipid profile from 4/71 showed a LDL of 103.
# 22847       22847   His lipid profile from 4/71 showed a LDL of 103.
# 23623       23623      Calculated LDL         161*  50-160 mg/dL ...
# 24550       24550                                       LDL was 125.
# 24605       24605     Her LDL is 116 ono 2/87 and has DM, goal <100.
#
#           label        file    Class0    Class1    Class2    Class3 predClass  \
# 1641   high LDL  131-01.xml  0.999933  0.000029  0.000013  0.000025    Class0
# 1642   high LDL  131-01.xml  0.999937  0.000027  0.000012  0.000024    Class0
# 1643   high LDL  131-01.xml  0.999940  0.000025  0.000011  0.000024    Class0
# 2825   high LDL  134-03.xml  0.859804  0.078042  0.025564  0.036589    Class0
# 3759   high LDL  138-03.xml  0.961764  0.022053  0.006548  0.009635    Class0
# 3891   high LDL  139-02.xml  0.791359  0.116614  0.039480  0.052547    Class0
# 4543   high LDL  162-04.xml  0.999779  0.000093  0.000036  0.000092    Class0
# 4753   high LDL  163-03.xml  0.810808  0.101496  0.034903  0.052792    Class0
# 6186   high LDL  169-01.xml  0.770852  0.111234  0.041844  0.076070    Class0
# 6994   high LDL  193-05.xml  0.946269  0.027221  0.008476  0.018034    Class0
# 11443  high LDL  211-01.xml  0.881892  0.058585  0.019951  0.039572    Class0
# 11875  high LDL  214-01.xml  0.878586  0.066420  0.021535  0.033459    Class0
# 12294  high LDL  216-03.xml  0.999934  0.000029  0.000013  0.000025    Class0
# 12304  high LDL  216-03.xml  0.999938  0.000026  0.000011  0.000025    Class0
# 12309  high LDL  216-03.xml  0.997741  0.001024  0.000294  0.000941    Class0
# 14258  high LDL  236-02.xml  0.844789  0.080155  0.027318  0.047739    Class0
# 15354  high LDL  260-02.xml  0.849654  0.082634  0.027530  0.040182    Class0
# 15458  high LDL  260-03.xml  0.898919  0.051087  0.017667  0.032327    Class0
# 15525  high LDL  260-04.xml  0.005536  0.000745  0.000558  0.993161    Class3
# 18743  high LDL  318-01.xml  0.950550  0.024565  0.008175  0.016710    Class0
# 18932  high LDL  318-03.xml  0.947635  0.026487  0.008809  0.017068    Class0
# 19059  high LDL  319-01.xml  0.857727  0.079577  0.025910  0.036786    Class0
# 19167  high LDL  319-03.xml  0.999939  0.000025  0.000011  0.000025    Class0
# 19269  high LDL  340-03.xml  0.878972  0.070493  0.021970  0.028566    Class0
# 19410  high LDL  342-04.xml  0.939088  0.035510  0.010699  0.014703    Class0
# 21627  high LDL  372-02.xml  0.929895  0.034827  0.011362  0.023917    Class0
# 22780  high LDL  376-01.xml  0.953051  0.026830  0.007956  0.012164    Class0
# 22847  high LDL  376-02.xml  0.953051  0.026830  0.007956  0.012164    Class0
# 23623  high LDL  379-05.xml  0.995753  0.002276  0.000627  0.001344    Class0
# 24550  high LDL  386-02.xml  0.860918  0.078412  0.025583  0.035086    Class0
# 24605  high LDL  386-03.xml  0.939348  0.033707  0.010188  0.016757    Class0
#
#       predLabel
# 1641      Other
# 1642      Other
# 1643      Other
# 2825      Other
# 3759      Other
# 3891      Other
# 4543      Other
# 4753      Other
# 6186      Other
# 6994      Other
# 11443     Other
# 11875     Other
# 12294     Other
# 12304     Other
# 12309     Other
# 14258     Other
# 15354     Other
# 15458     Other
# 15525   mention
# 18743     Other
# 18932     Other
# 19059     Other
# 19167     Other
# 19269     Other
# 19410     Other
# 21627     Other
# 22780     Other
# 22847     Other
# 23623     Other
# 24550     Other
# 24605     Other

# %% [markdown]
# The entire class of 'high LDL' is getting predicted incorrectly as the model is not able to learn from the actual limits that determine high LDL levels.

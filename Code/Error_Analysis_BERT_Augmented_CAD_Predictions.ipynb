# %% [markdown]
# ## Error Analysis for CAD Predictions (BERT Augmented)

# %%
import os
import string
import random
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
import numpy as np

# %% [markdown]
# ### Test LABELS for TOKENS in TEST Dataset against BERT Outputs
#
# BERT Classifier has returned results for the tokens passed in 'test.tsv' file.  The returned values are probabilities, that need to be converted into equivalent class labels based on majority class.  Then, the class label should be compared against the actual label from the code above to extract the IO-Coding from the xml files.  This is a brute-force approach or a manual way of verifying the validity of the predictions

# %% [markdown]
# Read in results from BERT Predicitons to the above dataset
# The above dataset is derived from IO-Coding applied as done on the training set. This is what should be based on the annotation process. Nowe, we have to read in the predictions from bert, which is a set of class probabilities across all 3 classes and we have to merget that with the above dataset for comparison and error analysis.

# %% [markdown]
# ### Data File Names

# %% [markdown]
# * Test files with Labels and Filenames : /data_for_bert_sent/test_files_with_labels/*_testfile.csv
# * Bert label mapping /data_for_bert_sent/test_files_with_labels/*_labelmapping.csv
# * BERT evaluation /data_for_bert_sent/BERT_run_results/*_eval_results.txt

# %%
print(os.path.dirname(os.path.abspath('__file__')))
# Out:
# C:\Users\Kalyan\Documents\Anu\W266 - NLP\Final Project\lheart-disease-risk-prediction\Code

# %% [markdown]
# ### CAD Indicator

# %%
# read in the test files with labels

CI_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/cad_ind_testfile.csv")

# %%
CI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
CI_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...   test
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Augmented CAD Indicator model and specify columns as the actual file has no header
bert_aug_CI_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_cad_ind_output_results_test_results.tsv", sep='\t')
                               
bert_aug_CI_results.columns=["Class0", "Class1", "Class2", "Class3", "Class4"]

# %%
bert_aug_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4
# 0  0.999926  0.000020  0.000027  0.000016  0.000010
# 1  0.999272  0.000397  0.000152  0.000023  0.000156
# 2  0.999398  0.000318  0.000139  0.000020  0.000124
# 3  0.999571  0.000220  0.000102  0.000020  0.000087
# 4  0.999926  0.000021  0.000029  0.000015  0.000010

# %%
bert_aug_CI_results['predClass'] = bert_aug_CI_results.idxmax(axis=1)

# %%
bert_aug_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass
# 0  0.999926  0.000020  0.000027  0.000016  0.000010    Class0
# 1  0.999272  0.000397  0.000152  0.000023  0.000156    Class0
# 2  0.999398  0.000318  0.000139  0.000020  0.000124    Class0
# 3  0.999571  0.000220  0.000102  0.000020  0.000087    Class0
# 4  0.999926  0.000021  0.000029  0.000015  0.000010    Class0

# %%
bert_aug_CI_results['predClass'].value_counts()
# Out:
# Class0    20640
# Class2      329
# Class1      270
# Class3      126
# Class4       47
# Name: predClass, dtype: int64

# %%
def CI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'event'
    elif (classlabel=='Class2'):
        return 'mention'
    elif (classlabel=='Class3'):
        return 'symptom'
    elif (classlabel=='Class4'):
        return 'test'
    else:
        return 'Other'

# %%
bert_aug_CI_results['predLabel'] = bert_aug_CI_results['predClass'].apply(CI_set_labels)

bert_aug_CI_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass predLabel
# 0  0.999926  0.000020  0.000027  0.000016  0.000010    Class0     Other
# 1  0.999272  0.000397  0.000152  0.000023  0.000156    Class0     Other
# 2  0.999398  0.000318  0.000139  0.000020  0.000124    Class0     Other
# 3  0.999571  0.000220  0.000102  0.000020  0.000087    Class0     Other
# 4  0.999926  0.000021  0.000029  0.000015  0.000010    Class0     Other
# 5  0.999921  0.000025  0.000029  0.000013  0.000012    Class0     Other
# 6  0.999928  0.000021  0.000026  0.000014  0.000010    Class0     Other
# 7  0.999854  0.000061  0.000039  0.000014  0.000032    Class0     Other
# 8  0.999920  0.000020  0.000027  0.000023  0.000010    Class0     Other
# 9  0.999883  0.000050  0.000039  0.000016  0.000013    Class0     Other

# %%
# validating the counts by label
bert_aug_CI_results['predLabel'].value_counts()
# Out:
# Other      20640
# mention      329
# event        270
# symptom      126
# test          47
# Name: predLabel, dtype: int64

# %%
CI_combined = pd.concat([CI_test, bert_aug_CI_results], axis=1)

# %%
CI_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999926  0.000020
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999272  0.000397
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999398  0.000318
# 3           3             MR:\t8249813  Other  110-03.xml  0.999571  0.000220
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.999926  0.000021
#
#      Class2    Class3    Class4 predClass predLabel
# 0  0.000027  0.000016  0.000010    Class0     Other
# 1  0.000152  0.000023  0.000156    Class0     Other
# 2  0.000139  0.000020  0.000124    Class0     Other
# 3  0.000102  0.000020  0.000087    Class0     Other
# 4  0.000029  0.000015  0.000010    Class0     Other

# %%
CI_combined[CI_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence    label  \
# 65             65                              ASSESSMENT AND PLAN:     Other
# 85             85                         History of Present Illness    Other
# 97             97                                           Problems    Other
# 156           156                                         Impression    Other
# 160           160  Doubt pneumonia (no cough or fever, lungs clea...    Other
# 179           179  HISTORY OF PRESENT ILLNESS:  In essence, this ...    Other
# 191           191  vomiting, and some shortness of breath associa...    Other
# 250           250  His past medical history is significant for hy...    Other
# 252           252  He was able to exercise for 8 minutes and 4 se...    Other
# 288           288  He is a 54-year-old man with obesity, dyslipid...    Other
# 289           289  He complained of fatigue and exertional throat...     test
# 290           290  Cardiac catheterization performed by Dr. Lesli...     test
# 341           341                 PAST MEDICAL HISTORY:  As per HPI.    Other
# 418           418                     CC: fever, lethargy, confusion    Other
# 438           438  chronic urethral strictures and bladder calcul...    Other
# 541           541                                   Dysthymia MAJOR     Other
# 575           575  I suspect she is feeling better with rate cont...    Other
# 576           576                            Coronary artery disease  mention
# 734           734  Patient reports a history of angina stating th...  symptom
# 753           753                                                 4.    Other
# 765           765  Family History:  There is no family history of...    Other
# 831           831                             ASA Physical Status II    Other
# 873           873  PSH:   Aortic valve replacement 3/17, ERCP wit...    Other
# 924           924                               Patient is a 54 y.o.    Other
# 934           934  PMH: S/p mechanical aortic valve replacement, ...    Other
# 975           975     The patient's complicated cardiac history d...    Other
# 1023         1023                                                 4.    Other
# 1024         1024                           Coronary artery disease.  mention
# 1102         1102  He will need outpatient follow up with Dr. Wer...    Other
# 1149         1149                             ASSESSMENT AND PLAN:      Other
# ...           ...                                                ...      ...
# 20474       20474                           Allergic rhinitis MAJOR     Other
# 20482       20482                                     Major Problems    Other
# 20495       20495  He has had no sinus pains, headache, or recent...    Other
# 20496       20496                        Angina pectoris STATUS POST  symptom
# 20540       20540                               Past medical history    Other
# 20594       20594    The patient's symptoms and exam as well as E...    Other
# 20615       20615                                             \t\t\t    Other
# 20630       20630                                     Major Problems    Other
# 20644       20644  He has had no sinus pains, headache, or recent...    Other
# 20645       20645                        Angina pectoris STATUS POST  symptom
# 20648       20648               ETT 3/2091 mild ant./basal ischemia.     test
# 20758       20758                                                 3.    Other
# 20768       20768                        No strong indication given.    Other
# 20862       20862              Asked him to check pre dinner sugars.    Other
# 21076       21076                  c.\tIncisional with movement vs ?    Other
# 21102       21102  She in fact has undergone lower extremity bypa...    Other
# 21108       21108  She has never had any chest discomfort, shortn...    Other
# 21109       21109  She does have a strong family history of coron...    Other
# 21110       21110  She has a report of a prior EKG with suggestio...    event
# 21115       21115  She is unfortunately limited significantly by ...    Other
# 21120       21120  She works as a Senior Manager of Broadcasting ...    Other
# 21134       21134  An EKG done in our clinic today demonstrates a...    Other
# 21135       21135  There is left atrial enlargement and Q-waves i...    Other
# 21136       21136  There are also Q-waves in lead III and aVF, wh...    event
# 21138       21138  She appears to have an excellent functional ca...    Other
# 21139       21139  However, I am concerned by her electrocardiogr...  mention
# 21148       21148  As I mentioned because her functional capacity...    Other
# 21221       21221                                           No edema    Other
# 21341       21341                       legs w/ essentially no edema    Other
# 21412       21412                         Tannon Jose Olivares, M.D.    Other
#
#              file    Class0    Class1    Class2    Class3    Class4 predClass  \
# 65     110-03.xml  0.000793  0.000240  0.000303  0.998302  0.000362    Class3
# 85     110-04.xml  0.000804  0.993561  0.004396  0.000401  0.000837    Class1
# 97     110-04.xml  0.001814  0.003055  0.994300  0.000270  0.000561    Class2
# 156    110-04.xml  0.001314  0.996738  0.000688  0.000601  0.000660    Class1
# 160    110-04.xml  0.001491  0.996681  0.000750  0.000558  0.000520    Class1
# 179    111-04.xml  0.002081  0.000973  0.996085  0.000404  0.000457    Class2
# 191    111-04.xml  0.002119  0.000964  0.996061  0.000422  0.000434    Class2
# 250    112-03.xml  0.397554  0.004942  0.000649  0.587603  0.009252    Class3
# 252    112-03.xml  0.000901  0.000225  0.000318  0.998172  0.000384    Class3
# 288    112-04.xml  0.000908  0.000529  0.000285  0.000495  0.997784    Class4
# 289    112-04.xml  0.053236  0.008662  0.000666  0.001351  0.936086    Class4
# 290    112-04.xml  0.001716  0.996366  0.000925  0.000404  0.000590    Class1
# 341    113-04.xml  0.002144  0.001004  0.996020  0.000385  0.000447    Class2
# 418    113-05.xml  0.001757  0.001019  0.996210  0.000597  0.000417    Class2
# 438    113-05.xml  0.001338  0.002620  0.995140  0.000270  0.000632    Class2
# 541    115-04.xml  0.002498  0.001325  0.995361  0.000331  0.000485    Class2
# 575    115-04.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 576    115-04.xml  0.002247  0.000298  0.000363  0.996760  0.000332    Class3
# 734    117-02.xml  0.001582  0.000260  0.000353  0.997506  0.000299    Class3
# 753    117-02.xml  0.001026  0.000253  0.000310  0.998041  0.000370    Class3
# 765    117-02.xml  0.001528  0.996584  0.000871  0.000390  0.000626    Class1
# 831    117-02.xml  0.000870  0.000293  0.000338  0.998194  0.000305    Class3
# 873    118-02.xml  0.004302  0.993681  0.000998  0.000420  0.000599    Class1
# 924    118-04.xml  0.001854  0.994687  0.002105  0.000954  0.000399    Class1
# 934    118-04.xml  0.060062  0.935167  0.003376  0.000605  0.000789    Class1
# 975    118-05.xml  0.002099  0.001025  0.996006  0.000387  0.000483    Class2
# 1023   118-05.xml  0.002440  0.001284  0.995454  0.000340  0.000482    Class2
# 1024   118-05.xml  0.000555  0.000454  0.000353  0.000322  0.998315    Class4
# 1102   118-05.xml  0.002190  0.001023  0.995933  0.000353  0.000501    Class2
# 1149   119-02.xml  0.000954  0.000268  0.000300  0.998089  0.000389    Class3
# ...           ...       ...       ...       ...       ...       ...       ...
# 20474  268-03.xml  0.000887  0.000245  0.000305  0.998148  0.000415    Class3
# 20482  268-03.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 20495  268-03.xml  0.000846  0.000245  0.000312  0.998193  0.000404    Class3
# 20496  268-03.xml  0.005092  0.002056  0.000685  0.949512  0.042654    Class3
# 20540  268-03.xml  0.001127  0.996790  0.001146  0.000439  0.000498    Class1
# 20594  268-03.xml  0.001382  0.996758  0.000734  0.000546  0.000580    Class1
# 20615  268-04.xml  0.001374  0.996715  0.001026  0.000413  0.000472    Class1
# 20630  268-04.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 20644  268-04.xml  0.000846  0.000245  0.000312  0.998193  0.000404    Class3
# 20645  268-04.xml  0.005092  0.002056  0.000685  0.949512  0.042654    Class3
# 20648  268-04.xml  0.001263  0.995217  0.000569  0.000502  0.002448    Class1
# 20758  269-01.xml  0.002532  0.001612  0.994987  0.000284  0.000584    Class2
# 20768  269-01.xml  0.001214  0.000490  0.000285  0.997456  0.000554    Class3
# 20862  269-02.xml  0.014462  0.516462  0.257656  0.000369  0.211051    Class1
# 21076  269-04.xml  0.021807  0.009049  0.001044  0.961690  0.006410    Class3
# 21102  317-01.xml  0.390915  0.601116  0.004100  0.000538  0.003331    Class1
# 21108  317-01.xml  0.008086  0.758242  0.230902  0.000834  0.001936    Class1
# 21109  317-01.xml  0.001409  0.996721  0.000978  0.000393  0.000499    Class1
# 21110  317-01.xml  0.002908  0.001138  0.995149  0.000369  0.000436    Class2
# 21115  317-01.xml  0.003264  0.992900  0.002570  0.000525  0.000741    Class1
# 21120  317-01.xml  0.024859  0.971967  0.001609  0.000775  0.000790    Class1
# 21134  317-01.xml  0.001598  0.996602  0.000873  0.000480  0.000448    Class1
# 21135  317-01.xml  0.002256  0.995755  0.001142  0.000433  0.000415    Class1
# 21136  317-01.xml  0.202298  0.789549  0.003625  0.002226  0.002302    Class1
# 21138  317-01.xml  0.001478  0.995950  0.001496  0.000318  0.000758    Class1
# 21139  317-01.xml  0.008959  0.001830  0.988213  0.000512  0.000486    Class2
# 21148  317-01.xml  0.002894  0.001186  0.995101  0.000394  0.000425    Class2
# 21221  371-04.xml  0.001638  0.001272  0.996237  0.000332  0.000520    Class2
# 21341  371-05.xml  0.001635  0.001283  0.996224  0.000332  0.000526    Class2
# 21412  371-05.xml       NaN       NaN       NaN       NaN       NaN       NaN
#
#       predLabel
# 65      symptom
# 85        event
# 97      mention
# 156       event
# 160       event
# 179     mention
# 191     mention
# 250     symptom
# 252     symptom
# 288        test
# 289        test
# 290       event
# 341     mention
# 418     mention
# 438     mention
# 541     mention
# 575     mention
# 576     symptom
# 734     symptom
# 753     symptom
# 765       event
# 831     symptom
# 873       event
# 924       event
# 934       event
# 975     mention
# 1023    mention
# 1024       test
# 1102    mention
# 1149    symptom
# ...         ...
# 20474   symptom
# 20482   mention
# 20495   symptom
# 20496   symptom
# 20540     event
# 20594     event
# 20615     event
# 20630   mention
# 20644   symptom
# 20645   symptom
# 20648     event
# 20758   mention
# 20768   symptom
# 20862     event
# 21076   symptom
# 21102     event
# 21108     event
# 21109     event
# 21110   mention
# 21115     event
# 21120     event
# 21134     event
# 21135     event
# 21136     event
# 21138     event
# 21139   mention
# 21148   mention
# 21221   mention
# 21341   mention
# 21412       NaN
#
# [773 rows x 11 columns]

# %%
CI_test_labels = CI_combined['label']
CI_pred_labels = CI_combined['predLabel']

#print(type(CI_pred_labels))

# %%
accuracy_score(CI_test_labels, CI_pred_labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c96c08e29190> in <module>()
# ----> 1 accuracy_score(CI_test_labels, CI_pred_labels)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
# ---> 73     type_pred = type_of_target(y_pred)
#      74
#      75     y_type = set([type_true, type_pred])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     281         aux = ar[perm]
#     282     else:
# --> 283         ar.sort()
#     284         aux = ar
#     285     flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
print(classification_report(CI_pred_labels, CI_test_labels))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-111468c18669> in <module>()
# ----> 1 print(classification_report(CI_pred_labels, CI_test_labels))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1522     """
#    1523
# -> 1524     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1525
#    1526     labels_given = True
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      70     """
#      71     check_consistent_length(y_true, y_pred)
# ---> 72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     281         aux = ar[perm]
#     282     else:
# --> 283         ar.sort()
#     284         aux = ar
#     285     flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
unique_label = np.unique(CI_test_labels)
print(pd.DataFrame(confusion_matrix(CI_test_labels, CI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-6a1c2f5e04c6> in <module>()
#       1 unique_label = np.unique(CI_test_labels)
# ----> 2 print(pd.DataFrame(confusion_matrix(CI_test_labels, CI_pred_labels, labels=unique_label),
#       3                    index=['true:{:}'.format(x) for x in unique_label],
#       4                    columns=['pred:{:}'.format(x) for x in unique_label]))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
# ---> 73     type_pred = type_of_target(y_pred)
#      74
#      75     y_type = set([type_true, type_pred])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     281         aux = ar[perm]
#     282     else:
# --> 283         ar.sort()
#     284         aux = ar
#     285     flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %% [markdown]
# ### CAD Time

# %%
# read in the test files with labels

CT_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/cad_tim_testfile.csv")

# %%
CI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
CI_test.head(10)

# %%
# read in the test results captured for BERT Augmented CAD model and specify columns as the actual file has no header
bert_CI_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_cad_time_output_results_test_results.tsv", sep='\t')
                               
bert_CI_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_CI_results.head()

# %%
bert_CI_results['predClass'] = bert_CI_results.idxmax(axis=1)

# %%
bert_CI_results.head()

# %%
bert_CI_results['predClass'].value_counts()

# %%
def CI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'after dct'
    elif (classlabel=='Class2'):
        return 'before dct'
    elif (classlabel=='Class3'):
        return 'during dct'
    else:
        return 'Other'

# %%
bert_CI_results['predLabel'] = bert_CI_results['predClass'].apply(CI_set_labels)

bert_CI_results.head(10)

# %%
# validating the counts by label
bert_CI_results['predLabel'].value_counts()

# %%
CI_combined = pd.concat([CI_test, bert_CI_results], axis=1)

# %%
CI_combined.head()

# %%
CI_combined[CI_combined['predLabel']!='Other']

# %%
CI_test_labels = CI_combined['label']
CI_pred_labels = CI_combined['predLabel']

#print(type(CI_test_labels))

# %%
accuracy_score(CI_test_labels, CI_pred_labels)

# %%
print(classification_report(CI_pred_labels, CI_test_labels))

# %%
unique_label = np.unique(CI_test_labels)
print(pd.DataFrame(confusion_matrix(CI_test_labels, CI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))

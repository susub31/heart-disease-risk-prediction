# %% [markdown]
# ## Error Analysis for CAD Predictions (BERT Augmented)

# %%
import os
import string
import random
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
import numpy as np

# %% [markdown]
# ### Data File Names

# %% [markdown]
# * Test files with Labels and Filenames : /data_for_bert_sent/test_files_with_labels/*_testfile.csv
# * Bert label mapping /data_for_bert_sent/test_files_with_labels/*_labelmapping.csv
# * BERT evaluation /data_for_bert_sent/BERT_run_results/*_eval_results.txt

# %%
print(os.path.dirname(os.path.abspath('__file__')))
# Out:
# C:\Users\Kalyan\Documents\Anu\W266 - NLP\Final Project\lheart-disease-risk-prediction\Code

# %% [markdown]
# ### CAD Indicator

# %%
# read in the test files with labels

CI_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/cad_ind_testfile.csv")

# %%
CI_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
CI_test.head(10)
# Out:
#    sentenceId                                           sentence  label  \
# 0           0                            Record date: 2080-02-18  Other
# 1           1                             SDU JAR Admission Note  Other
# 2           2                            Name: \t Yosef Villegas  Other
# 3           3                                       MR:\t8249813  Other
# 4           4                                    DOA:  \t2/17/80  Other
# 5           5                                PCP:  Gilbert Perez  Other
# 6           6                                  Attending: YBARRA  Other
# 7           7                                         CODE: FULL  Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...   test
# 9           9  Pt has had increasing CP and SOB on exertion f...  Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
CI_test['label'].value_counts()
# Out:
# Other      20642
# event        296
# mention      293
# symptom      113
# test          69
# Name: label, dtype: int64

# %%
# read in the test results captured for BERT Augmented CAD Indicator model and specify columns as the actual file has no header
bert_aug_CI_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_cad_ind_output_results_test_results.tsv", sep='\t', header=None)
                               
bert_aug_CI_results.columns=["Class0", "Class1", "Class2", "Class3", "Class4"]

# %%
bert_aug_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4
# 0  0.999926  0.000024  0.000023  0.000014  0.000013
# 1  0.999926  0.000020  0.000027  0.000016  0.000010
# 2  0.999272  0.000397  0.000152  0.000023  0.000156
# 3  0.999398  0.000318  0.000139  0.000020  0.000124
# 4  0.999571  0.000220  0.000102  0.000020  0.000087

# %%
bert_aug_CI_results['predClass'] = bert_aug_CI_results.idxmax(axis=1)

# %%
bert_aug_CI_results.head()
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass
# 0  0.999926  0.000024  0.000023  0.000014  0.000013    Class0
# 1  0.999926  0.000020  0.000027  0.000016  0.000010    Class0
# 2  0.999272  0.000397  0.000152  0.000023  0.000156    Class0
# 3  0.999398  0.000318  0.000139  0.000020  0.000124    Class0
# 4  0.999571  0.000220  0.000102  0.000020  0.000087    Class0

# %%
bert_aug_CI_results['predClass'].value_counts()
# Out:
# Class0    20641
# Class2      329
# Class1      270
# Class3      126
# Class4       47
# Name: predClass, dtype: int64

# %%
def CI_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'event'
    elif (classlabel=='Class2'):
        return 'mention'
    elif (classlabel=='Class3'):
        return 'symptom'
    elif (classlabel=='Class4'):
        return 'test'
    else:
        return 'Other'

# %%
bert_aug_CI_results['predLabel'] = bert_aug_CI_results['predClass'].apply(CI_set_labels)

bert_aug_CI_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3    Class4 predClass predLabel
# 0  0.999926  0.000024  0.000023  0.000014  0.000013    Class0     Other
# 1  0.999926  0.000020  0.000027  0.000016  0.000010    Class0     Other
# 2  0.999272  0.000397  0.000152  0.000023  0.000156    Class0     Other
# 3  0.999398  0.000318  0.000139  0.000020  0.000124    Class0     Other
# 4  0.999571  0.000220  0.000102  0.000020  0.000087    Class0     Other
# 5  0.999926  0.000021  0.000029  0.000015  0.000010    Class0     Other
# 6  0.999921  0.000025  0.000029  0.000013  0.000012    Class0     Other
# 7  0.999928  0.000021  0.000026  0.000014  0.000010    Class0     Other
# 8  0.999854  0.000061  0.000039  0.000014  0.000032    Class0     Other
# 9  0.999920  0.000020  0.000027  0.000023  0.000010    Class0     Other

# %%
# validating the counts by label
bert_aug_CI_results['predLabel'].value_counts()
# Out:
# Other      20641
# mention      329
# event        270
# symptom      126
# test          47
# Name: predLabel, dtype: int64

# %%
CI_combined = pd.concat([CI_test, bert_aug_CI_results], axis=1)

# %%
CI_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999926  0.000024
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999926  0.000020
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999272  0.000397
# 3           3             MR:\t8249813  Other  110-03.xml  0.999398  0.000318
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.999571  0.000220
#
#      Class2    Class3    Class4 predClass predLabel
# 0  0.000023  0.000014  0.000013    Class0     Other
# 1  0.000027  0.000016  0.000010    Class0     Other
# 2  0.000152  0.000023  0.000156    Class0     Other
# 3  0.000139  0.000020  0.000124    Class0     Other
# 4  0.000102  0.000020  0.000087    Class0     Other

# %%
CI_combined[CI_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence    label  \
# 66             66  70 yo M with multiple cardiac risk factors and...  symptom
# 86             86            71 yo M with CAD, s/p CABG x 4 in 3/80.    event
# 98             98        Coronary artery disease    : s/p CABG x ...    event
# 157           157  Sternal pain-- non-exertional, reproducible by...    event
# 161           161  Pericarditis a possibility (he had post-op per...    event
# 180           180  65-year-old male with known history of CAD who...  mention
# 192           192  PAST MEDICAL HISTORY:  Hypertension, diabetes,...  mention
# 251           251  Prior to his pacemaker placement, an exercise ...    Other
# 253           253  The test was terminated for 7/10 substernal ch...     test
# 289           289  He complained of fatigue and exertional throat...     test
# 290           290  Cardiac catheterization performed by Dr. Lesli...     test
# 291           291  He received a 3mm stent, postdilated to 3.5mm,...    event
# 342           342                        In addition, CAD, diabetes,  mention
# 419           419  HPI: 57M who lives in NH and has h/o severe MS...  mention
# 439           439  CAD s/p STEMI in 2091 in setting of sepsis/pre...  mention
# 542           542                     Coronary artery disease MAJOR   mention
# 576           576                            Coronary artery disease  mention
# 577           577                                  No angina or SOB.    Other
# 735           735  Describes angina as left-sided anterior chest ...  symptom
# 754           754                                  History of angina  symptom
# 766           766           Family history positive for MI, diabetes    Other
# 832           832  71 year old female with a history of diabetes,...  symptom
# 874           874                                              CABG.    event
# 925           925  male with h/o aortic valve replacement, CHF, a...    Other
# 935           935                                     PSH: CABG, AVR    event
# 976           976  He had preserved LV function and pre-operative...     test
# 1024         1024                           Coronary artery disease.  mention
# 1025         1025  Preoperative cardiac catheterization on 03/11/...     test
# 1103         1103                                               CAD.  mention
# 1150         1150           (1)  Angina/hypertension/hyperlipidemia.  symptom
# ...           ...                                                ...      ...
# 20470       20470                     Coronary artery disease MAJOR   mention
# 20475       20475                  Angina pectoris MAJOR STATUS POST  symptom
# 20483       20483                            Coronary artery disease  mention
# 20496       20496                        Angina pectoris STATUS POST  symptom
# 20497       20497            Unstable angina 1/86 cath lad stenosis.     test
# 20541       20541    History of coronary artery bypass surgery in...    event
# 20595       20595  Of note, the patient had a history of paroxysm...    Other
# 20616       20616    Followup of recent MI and multiple medical p...    event
# 20631       20631                            Coronary artery disease  mention
# 20645       20645                        Angina pectoris STATUS POST  symptom
# 20646       20646            Unstable angina 1/86 cath lad stenosis.  symptom
# 20649       20649         S/P MI 12/92 with cardiac cath, stent RCA.    event
# 20759       20759  Coronary artery disease:  Patient had mildly a...  mention
# 20769       20769                       No MI or symptomatic angina.    Other
# 20863       20863  Coronary disease: patient had a mild posterior...     test
# 21077       21077                                           ischemic    Other
# 21103       21103  Specifically, she is status post a right fem-p...    Other
# 21109       21109  She does have a strong family history of coron...    Other
# 21110       21110  She has a report of a prior EKG with suggestio...    event
# 21111       21111  She has never had any evaluation for underlyin...  mention
# 21116       21116  Her past medical history is as noted above inc...    Other
# 21121       21121  As I mentioned previously, her family history ...    Other
# 21135       21135  There is left atrial enlargement and Q-waves i...    Other
# 21136       21136  There are also Q-waves in lead III and aVF, wh...    event
# 21137       21137  In summary, Ms. Hendricks is a lovely 52-year-...    Other
# 21139       21139  However, I am concerned by her electrocardiogr...  mention
# 21140       21140  As such, I think that it would be wise to bett...    Other
# 21149       21149  This is more in order to give us a sense of th...  mention
# 21222       21222  A/P: 71F w/ MMPs including CAD w/ recent norma...  mention
# 21342       21342  A/P: 71F w/ MMPs including CAD w/ recent norma...  mention
#
#              file    Class0    Class1    Class2    Class3    Class4 predClass  \
# 66     110-03.xml  0.000793  0.000240  0.000303  0.998302  0.000362    Class3
# 86     110-04.xml  0.000804  0.993561  0.004396  0.000401  0.000837    Class1
# 98     110-04.xml  0.001814  0.003055  0.994300  0.000270  0.000561    Class2
# 157    110-04.xml  0.001314  0.996738  0.000688  0.000601  0.000660    Class1
# 161    110-04.xml  0.001491  0.996681  0.000750  0.000558  0.000520    Class1
# 180    111-04.xml  0.002081  0.000973  0.996085  0.000404  0.000457    Class2
# 192    111-04.xml  0.002119  0.000964  0.996061  0.000422  0.000434    Class2
# 251    112-03.xml  0.397554  0.004942  0.000649  0.587603  0.009252    Class3
# 253    112-03.xml  0.000901  0.000225  0.000318  0.998172  0.000384    Class3
# 289    112-04.xml  0.000908  0.000529  0.000285  0.000495  0.997784    Class4
# 290    112-04.xml  0.053236  0.008662  0.000666  0.001351  0.936086    Class4
# 291    112-04.xml  0.001716  0.996366  0.000925  0.000404  0.000590    Class1
# 342    113-04.xml  0.002144  0.001004  0.996020  0.000385  0.000447    Class2
# 419    113-05.xml  0.001757  0.001019  0.996210  0.000597  0.000417    Class2
# 439    113-05.xml  0.001338  0.002620  0.995140  0.000270  0.000632    Class2
# 542    115-04.xml  0.002498  0.001325  0.995361  0.000331  0.000485    Class2
# 576    115-04.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 577    115-04.xml  0.002247  0.000298  0.000363  0.996760  0.000332    Class3
# 735    117-02.xml  0.001582  0.000260  0.000353  0.997506  0.000299    Class3
# 754    117-02.xml  0.001026  0.000253  0.000310  0.998041  0.000370    Class3
# 766    117-02.xml  0.001528  0.996584  0.000871  0.000390  0.000626    Class1
# 832    117-02.xml  0.000870  0.000293  0.000338  0.998194  0.000305    Class3
# 874    118-02.xml  0.004302  0.993681  0.000998  0.000420  0.000599    Class1
# 925    118-04.xml  0.001854  0.994687  0.002105  0.000954  0.000399    Class1
# 935    118-04.xml  0.060062  0.935167  0.003376  0.000605  0.000789    Class1
# 976    118-05.xml  0.002099  0.001025  0.996006  0.000387  0.000483    Class2
# 1024   118-05.xml  0.002440  0.001284  0.995454  0.000340  0.000482    Class2
# 1025   118-05.xml  0.000555  0.000454  0.000353  0.000322  0.998315    Class4
# 1103   118-05.xml  0.002190  0.001023  0.995933  0.000353  0.000501    Class2
# 1150   119-02.xml  0.000954  0.000268  0.000300  0.998089  0.000389    Class3
# ...           ...       ...       ...       ...       ...       ...       ...
# 20470  268-03.xml  0.002498  0.001325  0.995361  0.000331  0.000485    Class2
# 20475  268-03.xml  0.000887  0.000245  0.000305  0.998148  0.000415    Class3
# 20483  268-03.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 20496  268-03.xml  0.000846  0.000245  0.000312  0.998193  0.000404    Class3
# 20497  268-03.xml  0.005092  0.002056  0.000685  0.949512  0.042654    Class3
# 20541  268-03.xml  0.001127  0.996790  0.001146  0.000439  0.000498    Class1
# 20595  268-03.xml  0.001382  0.996758  0.000734  0.000546  0.000580    Class1
# 20616  268-04.xml  0.001374  0.996715  0.001026  0.000413  0.000472    Class1
# 20631  268-04.xml  0.002512  0.001391  0.995265  0.000329  0.000502    Class2
# 20645  268-04.xml  0.000846  0.000245  0.000312  0.998193  0.000404    Class3
# 20646  268-04.xml  0.005092  0.002056  0.000685  0.949512  0.042654    Class3
# 20649  268-04.xml  0.001263  0.995217  0.000569  0.000502  0.002448    Class1
# 20759  269-01.xml  0.002532  0.001612  0.994987  0.000284  0.000584    Class2
# 20769  269-01.xml  0.001214  0.000490  0.000285  0.997456  0.000554    Class3
# 20863  269-02.xml  0.014462  0.516462  0.257656  0.000369  0.211051    Class1
# 21077  269-04.xml  0.021807  0.009049  0.001044  0.961690  0.006410    Class3
# 21103  317-01.xml  0.390915  0.601116  0.004100  0.000538  0.003331    Class1
# 21109  317-01.xml  0.008086  0.758242  0.230902  0.000834  0.001936    Class1
# 21110  317-01.xml  0.001409  0.996721  0.000978  0.000393  0.000499    Class1
# 21111  317-01.xml  0.002908  0.001138  0.995149  0.000369  0.000436    Class2
# 21116  317-01.xml  0.003264  0.992900  0.002570  0.000525  0.000741    Class1
# 21121  317-01.xml  0.024859  0.971967  0.001609  0.000775  0.000790    Class1
# 21135  317-01.xml  0.001598  0.996602  0.000873  0.000480  0.000448    Class1
# 21136  317-01.xml  0.002256  0.995755  0.001142  0.000433  0.000415    Class1
# 21137  317-01.xml  0.202298  0.789549  0.003625  0.002226  0.002302    Class1
# 21139  317-01.xml  0.001478  0.995950  0.001496  0.000318  0.000758    Class1
# 21140  317-01.xml  0.008959  0.001830  0.988213  0.000512  0.000486    Class2
# 21149  317-01.xml  0.002894  0.001186  0.995101  0.000394  0.000425    Class2
# 21222  371-04.xml  0.001638  0.001272  0.996237  0.000332  0.000520    Class2
# 21342  371-05.xml  0.001635  0.001283  0.996224  0.000332  0.000526    Class2
#
#       predLabel
# 66      symptom
# 86        event
# 98      mention
# 157       event
# 161       event
# 180     mention
# 192     mention
# 251     symptom
# 253     symptom
# 289        test
# 290        test
# 291       event
# 342     mention
# 419     mention
# 439     mention
# 542     mention
# 576     mention
# 577     symptom
# 735     symptom
# 754     symptom
# 766       event
# 832     symptom
# 874       event
# 925       event
# 935       event
# 976     mention
# 1024    mention
# 1025       test
# 1103    mention
# 1150    symptom
# ...         ...
# 20470   mention
# 20475   symptom
# 20483   mention
# 20496   symptom
# 20497   symptom
# 20541     event
# 20595     event
# 20616     event
# 20631   mention
# 20645   symptom
# 20646   symptom
# 20649     event
# 20759   mention
# 20769   symptom
# 20863     event
# 21077   symptom
# 21103     event
# 21109     event
# 21110     event
# 21111   mention
# 21116     event
# 21121     event
# 21135     event
# 21136     event
# 21137     event
# 21139     event
# 21140   mention
# 21149   mention
# 21222   mention
# 21342   mention
#
# [772 rows x 11 columns]

# %%
CI_test_labels = CI_combined['label']
CI_pred_labels = CI_combined['predLabel']
print(type(CI_test_labels))
print(type(CI_pred_labels))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
accuracy_score(CI_test_labels, CI_pred_labels)
# Out:
# 0.9766496987811143

# %%
print(classification_report(CI_pred_labels, CI_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       0.99      0.99      0.99     20641
#        event       0.56      0.61      0.59       270
#      mention       0.84      0.75      0.79       329
#      symptom       0.43      0.39      0.41       126
#         test       0.29      0.43      0.34        47
#
#    micro avg       0.98      0.98      0.98     21413
#    macro avg       0.62      0.63      0.62     21413
# weighted avg       0.98      0.98      0.98     21413

# %%
unique_label = np.unique(CI_test_labels)
print(pd.DataFrame(confusion_matrix(CI_test_labels, CI_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#               pred:Other  pred:event  pred:mention  pred:symptom  pred:test
# true:Other         20432          81            38            68         23
# true:event            87         166            35             4          4
# true:mention          25          19           246             3          0
# true:symptom          60           1             3            49          0
# true:test             37           3             7             2         20

# %%
 CI_combined[(CI_combined['label']!='Other') & (CI_combined['predLabel']=='Other')]
# Out:
#        sentenceId                                           sentence    label  \
# 8               8  HPI:  70 yo M with NIDDM admitted for cath aft...     test
# 12             12  MIBI was read as positive for moderate to seve...     test
# 60             60                  The ECG is positive for ischemia.     test
# 62             62  Findings are consistent with moderate to sever...     test
# 68             68  \tIschemia: Hx angina, MIBI positive for infer...  symptom
# 94             94  The pain does not remind him of his sx prior t...    event
# 182           182     walking, took 2 nitro and the pain got better.  mention
# 184           184             repeat episode relived by nitro again.  mention
# 198           198  PAST SURGICAL HISTORY:  Angioplasty with multi...    event
# 257           257  He tells me that he underwent testing at Wheat...     test
# 734           734  Patient reports a history of angina stating th...  symptom
# 833           833  Patient does describes episodes of angina that...  symptom
# 1378         1378  The perfusion scans showed a moderate, reversi...     test
# 1464         1464  He has been experiencing increasing DOE and ha...     test
# 1653         1653  The patient had symptoms of dyspnea on exertio...    event
# 2108         2108                               A BMS to RCA lesion.    event
# 2208         2208  Intervention on acute lesion today and possibl...    event
# 2255         2255  An emergent cardiac catheterization at that ti...     test
# 2259         2259  The RCA was large and dominant and had a proxi...     test
# 2786         2786  The chest did show a healed coronary artery by...    event
# 2947         2947  The patient had negative troponin studies but ...  symptom
# 2950         2950  He had increase in his Lipitor from 20 mg to 8...    event
# 2951         2951  Dr Gil RNHHe has a long history of cardiac dis...    event
# 2956         2956  Elevated microalbumin-to renal specialistAller...    event
# 2969         2969                                              EOMI.    event
# 3002         3002  HISTORY OF PRESENT ILLNESS:  The patient is a ...  mention
# 3005         3005                           Acute coronary syndrome.  mention
# 3008         3008                           EKG changes suggest IMI.    event
# 3010         3010                 She has had no further chest pain.  symptom
# 3073         3073  I saw her in consultation this afternoon for h...    event
# ...           ...                                                ...      ...
# 18104       18104  --3/69 ETT mibi METS 7, ECG non-dx due to subm...     test
# 18278       18278                       FHx:  \tMother: CAD s/p CABG  mention
# 18892       18892      REVIEW OF SYSTEMS:  He denies chest pain now.  symptom
# 18923       18923        FINAL DIAGNOSIS:  Unstable angina pectoris.  symptom
# 18991       18991  Emergency Medicine with complaints of chest pain.  symptom
# 19049       19049  and morphine for his chest pain, and admitted ...  symptom
# 19067       19067  female complaining of chest tightness lasting ...  symptom
# 19128       19128  comes in today with chest pain, onset iffy whi...  symptom
# 19219       19219  PHYSICAL EXAMINATION:  She is afebrile, heart ...    event
# 19263       19263  CLINICAL IMPRESSION:  Unstable angina with fre...  symptom
# 19313       19313    IMPRESSION:  End-stage ischemic cardiomyopathy.    event
# 19543       19543           Syncope, rule out myocardial infarction.    event
# 19619       19619  PHYSICAL EXAMINATION:  His blood pressure is 1...    event
# 20020       20020  The patient states the pain was a 10/10, worse...  symptom
# 20114       20114                                 here for her CABG.    event
# 20138       20138  She states that this pain is similar to her an...  symptom
# 20186       20186                 FINAL DIAGNOSIS:  Unstable angina.  symptom
# 20207       20207  History of Present Illness:  65 year old RH ge...  mention
# 20460       20460    Since his last visit, the patient has had tw...  symptom
# 20499       20499                ETT 3/2091 mild ant./basal ischemia     test
# 20648       20648               ETT 3/2091 mild ant./basal ischemia.     test
# 20710       20710  Heent   NC/AT, PERRL, EOMI, O/P clear without ...    event
# 20713       20713                         Cor   PMI at 5th ICS, MCL.    event
# 20928       20928  2/1/11 stroke 4/4/12 exercise sestamibi-SAH: S...     test
# 20932       20932  History of Present Illness: This 73 year-old h...     test
# 20992       20992  Intro:\t73 yo male s/p CABG with progressive a...    event
# 21002       21002                                           2)\tCAD   mention
# 21004       21004  i)\tOccluded RCA, subtotal circumflex and 95% ...     test
# 21006       21006                                          b)\tCABG     event
# 21016       21016  9)\tBPH  -  reports that he was in the process...  mention
#
#              file    Class0    Class1    Class2    Class3    Class4 predClass  \
# 8      110-03.xml  0.999854  0.000061  0.000039  0.000014  0.000032    Class0
# 12     110-03.xml  0.987264  0.004448  0.000225  0.000443  0.007619    Class0
# 60     110-03.xml  0.999758  0.000137  0.000039  0.000019  0.000048    Class0
# 62     110-03.xml  0.999890  0.000046  0.000027  0.000017  0.000019    Class0
# 68     110-03.xml  0.999115  0.000452  0.000253  0.000029  0.000151    Class0
# 94     110-04.xml  0.999881  0.000046  0.000030  0.000024  0.000019    Class0
# 182    111-04.xml  0.999917  0.000025  0.000029  0.000017  0.000013    Class0
# 184    111-04.xml  0.999922  0.000023  0.000029  0.000014  0.000012    Class0
# 198    111-04.xml  0.998454  0.001185  0.000233  0.000019  0.000109    Class0
# 257    112-03.xml  0.999806  0.000100  0.000037  0.000016  0.000041    Class0
# 734    117-02.xml  0.999907  0.000029  0.000023  0.000026  0.000015    Class0
# 833    117-02.xml  0.999892  0.000026  0.000023  0.000045  0.000014    Class0
# 1378   131-03.xml  0.999880  0.000048  0.000030  0.000016  0.000025    Class0
# 1464   131-03.xml  0.999929  0.000021  0.000023  0.000016  0.000011    Class0
# 1653   131-05.xml  0.850134  0.147170  0.001686  0.000655  0.000355    Class0
# 2108   134-04.xml  0.999915  0.000024  0.000036  0.000014  0.000010    Class0
# 2208   134-04.xml  0.997025  0.002668  0.000196  0.000049  0.000062    Class0
# 2255   134-05.xml  0.999697  0.000165  0.000047  0.000020  0.000072    Class0
# 2259   134-05.xml  0.986287  0.001532  0.000405  0.000135  0.011642    Class0
# 2786   137-01.xml  0.998163  0.001586  0.000125  0.000038  0.000087    Class0
# 2947   137-04.xml  0.999443  0.000135  0.000034  0.000187  0.000200    Class0
# 2950   137-04.xml  0.999531  0.000279  0.000146  0.000024  0.000021    Class0
# 2951   137-04.xml  0.997811  0.001878  0.000218  0.000035  0.000059    Class0
# 2956   137-04.xml  0.999858  0.000028  0.000067  0.000033  0.000014    Class0
# 2969   137-04.xml  0.998209  0.001066  0.000282  0.000035  0.000409    Class0
# 3002   138-03.xml  0.999062  0.000689  0.000113  0.000033  0.000103    Class0
# 3005   138-03.xml  0.999917  0.000030  0.000028  0.000013  0.000012    Class0
# 3008   138-03.xml  0.999901  0.000040  0.000030  0.000015  0.000014    Class0
# 3010   138-03.xml  0.999904  0.000030  0.000025  0.000025  0.000016    Class0
# 3073   138-04.xml  0.998706  0.001109  0.000085  0.000035  0.000066    Class0
# ...           ...       ...       ...       ...       ...       ...       ...
# 18104  260-04.xml  0.999908  0.000033  0.000032  0.000013  0.000015    Class0
# 18278  260-05.xml  0.998845  0.000594  0.000258  0.000029  0.000273    Class0
# 18892  263-02.xml  0.999895  0.000044  0.000026  0.000015  0.000019    Class0
# 18923  263-02.xml  0.999458  0.000049  0.000035  0.000424  0.000035    Class0
# 18991  263-04.xml  0.999927  0.000020  0.000023  0.000019  0.000010    Class0
# 19049  263-04.xml  0.999920  0.000019  0.000027  0.000024  0.000010    Class0
# 19067  264-01.xml  0.999885  0.000045  0.000026  0.000021  0.000023    Class0
# 19128  264-02.xml  0.999893  0.000024  0.000034  0.000039  0.000011    Class0
# 19219  264-03.xml  0.896848  0.066358  0.006442  0.000863  0.029488    Class0
# 19263  264-03.xml  0.998162  0.000148  0.000055  0.001548  0.000088    Class0
# 19313  264-04.xml  0.944815  0.053184  0.000593  0.000184  0.001224    Class0
# 19543  265-03.xml  0.998754  0.001017  0.000085  0.000022  0.000121    Class0
# 19619  265-04.xml  0.944490  0.034900  0.003080  0.000625  0.016905    Class0
# 20020  267-02.xml  0.999875  0.000033  0.000029  0.000047  0.000016    Class0
# 20114  267-03.xml  0.983339  0.015126  0.001206  0.000125  0.000204    Class0
# 20138  267-04.xml  0.996837  0.000265  0.001078  0.001732  0.000087    Class0
# 20186  267-04.xml  0.999851  0.000029  0.000022  0.000080  0.000018    Class0
# 20207  268-01.xml  0.999215  0.000485  0.000134  0.000114  0.000051    Class0
# 20460  268-03.xml  0.999914  0.000031  0.000021  0.000021  0.000014    Class0
# 20499  268-03.xml  0.999905  0.000038  0.000025  0.000014  0.000018    Class0
# 20648  268-04.xml  0.999899  0.000043  0.000023  0.000015  0.000020    Class0
# 20710  268-04.xml  0.999651  0.000224  0.000077  0.000015  0.000034    Class0
# 20713  268-04.xml  0.999930  0.000020  0.000024  0.000015  0.000011    Class0
# 20928  269-03.xml  0.999217  0.000401  0.000074  0.000028  0.000280    Class0
# 20932  269-03.xml  0.861050  0.129763  0.001939  0.000946  0.006303    Class0
# 20992  269-04.xml  0.999317  0.000345  0.000165  0.000021  0.000153    Class0
# 21002  269-04.xml  0.999333  0.000315  0.000162  0.000026  0.000164    Class0
# 21004  269-04.xml  0.981411  0.008991  0.002425  0.000148  0.007025    Class0
# 21006  269-04.xml  0.997814  0.001230  0.000340  0.000038  0.000578    Class0
# 21016  269-04.xml  0.999243  0.000357  0.000175  0.000026  0.000199    Class0
#
#       predLabel
# 8         Other
# 12        Other
# 60        Other
# 62        Other
# 68        Other
# 94        Other
# 182       Other
# 184       Other
# 198       Other
# 257       Other
# 734       Other
# 833       Other
# 1378      Other
# 1464      Other
# 1653      Other
# 2108      Other
# 2208      Other
# 2255      Other
# 2259      Other
# 2786      Other
# 2947      Other
# 2950      Other
# 2951      Other
# 2956      Other
# 2969      Other
# 3002      Other
# 3005      Other
# 3008      Other
# 3010      Other
# 3073      Other
# ...         ...
# 18104     Other
# 18278     Other
# 18892     Other
# 18923     Other
# 18991     Other
# 19049     Other
# 19067     Other
# 19128     Other
# 19219     Other
# 19263     Other
# 19313     Other
# 19543     Other
# 19619     Other
# 20020     Other
# 20114     Other
# 20138     Other
# 20186     Other
# 20207     Other
# 20460     Other
# 20499     Other
# 20648     Other
# 20710     Other
# 20713     Other
# 20928     Other
# 20932     Other
# 20992     Other
# 21002     Other
# 21004     Other
# 21006     Other
# 21016     Other
#
# [209 rows x 11 columns]

# %% [markdown]
# We see from the confusion matrix that there the CAD classes are confused with the "Other" class much more often than with the other CAD classes.  Though we augmented the data, we still see sparcity of CAD class compared to "Other"imbalance in the classes.

# %% [markdown]
# ### CAD Time

# %%
# read in the test files with labels

CT_test = pd.read_csv("data_for_bert_augmented/test_files_with_labels/cad_tim_testfile.csv")

# %%
CT_test.rename( columns={'Unnamed: 0' :'sentenceId'}, inplace=True )

# %%
CT_test.head(10)
# Out:
#    sentenceId                                           sentence       label  \
# 0           0                            Record date: 2080-02-18       Other
# 1           1                             SDU JAR Admission Note       Other
# 2           2                            Name: \t Yosef Villegas       Other
# 3           3                                       MR:\t8249813       Other
# 4           4                                    DOA:  \t2/17/80       Other
# 5           5                                PCP:  Gilbert Perez       Other
# 6           6                                  Attending: YBARRA       Other
# 7           7                                         CODE: FULL       Other
# 8           8  HPI:  70 yo M with NIDDM admitted for cath aft...  before DCT
# 9           9  Pt has had increasing CP and SOB on exertion f...       Other
#
#          file
# 0  110-03.xml
# 1  110-03.xml
# 2  110-03.xml
# 3  110-03.xml
# 4  110-03.xml
# 5  110-03.xml
# 6  110-03.xml
# 7  110-03.xml
# 8  110-03.xml
# 9  110-03.xml

# %%
# read in the test results captured for BERT Augmented CAD model and specify columns as the actual file has no header
bert_aug_CT_results = pd.read_csv("data_for_bert_augmented/bert_augmented_run_results/bert_aug_data_output_data_cad_time_output_results_test_results.tsv", sep='\t', header=None)
                               
bert_aug_CT_results.columns=["Class0", "Class1", "Class2", "Class3"]

# %%
bert_aug_CT_results.head()
# Out:
#      Class0    Class1    Class2    Class3
# 0  0.999842  0.000017  0.000123  0.000018
# 1  0.999850  0.000016  0.000117  0.000018
# 2  0.999801  0.000018  0.000158  0.000023
# 3  0.999784  0.000019  0.000176  0.000021
# 4  0.999831  0.000018  0.000130  0.000021

# %%
bert_aug_CT_results['predClass'] = bert_aug_CT_results.idxmax(axis=1)

# %%
bert_aug_CT_results.head()
# Out:
#      Class0    Class1    Class2    Class3 predClass
# 0  0.999842  0.000017  0.000123  0.000018    Class0
# 1  0.999850  0.000016  0.000117  0.000018    Class0
# 2  0.999801  0.000018  0.000158  0.000023    Class0
# 3  0.999784  0.000019  0.000176  0.000021    Class0
# 4  0.999831  0.000018  0.000130  0.000021    Class0

# %%
bert_aug_CT_results['predClass'].value_counts()
# Out:
# Class0    20667
# Class2      540
# Class1      106
# Class3      100
# Name: predClass, dtype: int64

# %%
def CT_set_labels(classlabel):
    if (classlabel=='Class1'):
        return 'after dct'
    elif (classlabel=='Class2'):
        return 'before dct'
    elif (classlabel=='Class3'):
        return 'during dct'
    else:
        return 'Other'

# %%
bert_aug_CT_results['predLabel'] = bert_aug_CI_results['predClass'].apply(CT_set_labels)

bert_aug_CT_results.head(10)
# Out:
#      Class0    Class1    Class2    Class3 predClass predLabel
# 0  0.999842  0.000017  0.000123  0.000018    Class0     Other
# 1  0.999850  0.000016  0.000117  0.000018    Class0     Other
# 2  0.999801  0.000018  0.000158  0.000023    Class0     Other
# 3  0.999784  0.000019  0.000176  0.000021    Class0     Other
# 4  0.999831  0.000018  0.000130  0.000021    Class0     Other
# 5  0.999863  0.000017  0.000102  0.000018    Class0     Other
# 6  0.999853  0.000017  0.000112  0.000017    Class0     Other
# 7  0.999870  0.000016  0.000097  0.000017    Class0     Other
# 8  0.999235  0.000022  0.000710  0.000033    Class0     Other
# 9  0.999778  0.000019  0.000183  0.000019    Class0     Other

# %%
# validating the counts by label
bert_aug_CT_results['predLabel'].value_counts()
# Out:
# Other         20688
# before dct      329
# after dct       270
# during dct      126
# Name: predLabel, dtype: int64

# %%
CT_combined = pd.concat([CT_test, bert_aug_CT_results], axis=1)

# %%
CT_combined.head()
# Out:
#    sentenceId                 sentence  label        file    Class0    Class1  \
# 0           0  Record date: 2080-02-18  Other  110-03.xml  0.999842  0.000017
# 1           1   SDU JAR Admission Note  Other  110-03.xml  0.999850  0.000016
# 2           2  Name: \t Yosef Villegas  Other  110-03.xml  0.999801  0.000018
# 3           3             MR:\t8249813  Other  110-03.xml  0.999784  0.000019
# 4           4          DOA:  \t2/17/80  Other  110-03.xml  0.999831  0.000018
#
#      Class2    Class3 predClass predLabel
# 0  0.000123  0.000018    Class0     Other
# 1  0.000117  0.000018    Class0     Other
# 2  0.000158  0.000023    Class0     Other
# 3  0.000176  0.000021    Class0     Other
# 4  0.000130  0.000021    Class0     Other

# %%
CT_combined[CT_combined['predLabel']!='Other']
# Out:
#        sentenceId                                           sentence  \
# 66             66  70 yo M with multiple cardiac risk factors and...
# 86             86            71 yo M with CAD, s/p CABG x 4 in 3/80.
# 98             98        Coronary artery disease    : s/p CABG x ...
# 157           157  Sternal pain-- non-exertional, reproducible by...
# 161           161  Pericarditis a possibility (he had post-op per...
# 180           180  65-year-old male with known history of CAD who...
# 192           192  PAST MEDICAL HISTORY:  Hypertension, diabetes,...
# 251           251  Prior to his pacemaker placement, an exercise ...
# 253           253  The test was terminated for 7/10 substernal ch...
# 291           291  He received a 3mm stent, postdilated to 3.5mm,...
# 342           342                        In addition, CAD, diabetes,
# 419           419  HPI: 57M who lives in NH and has h/o severe MS...
# 439           439  CAD s/p STEMI in 2091 in setting of sepsis/pre...
# 542           542                     Coronary artery disease MAJOR
# 576           576                            Coronary artery disease
# 577           577                                  No angina or SOB.
# 735           735  Describes angina as left-sided anterior chest ...
# 754           754                                  History of angina
# 766           766           Family history positive for MI, diabetes
# 832           832  71 year old female with a history of diabetes,...
# 874           874                                              CABG.
# 925           925  male with h/o aortic valve replacement, CHF, a...
# 935           935                                     PSH: CABG, AVR
# 976           976  He had preserved LV function and pre-operative...
# 1024         1024                           Coronary artery disease.
# 1103         1103                                               CAD.
# 1150         1150           (1)  Angina/hypertension/hyperlipidemia.
# 1187         1187           (1)  CAD/hypertension/diabetes mellitus.
# 1199         1199       Here for Angina/BP/DM check, no chest pains.
# 1214         1214                                 Angina    : STABLE
# ...           ...                                                ...
# 20470       20470                     Coronary artery disease MAJOR
# 20475       20475                  Angina pectoris MAJOR STATUS POST
# 20483       20483                            Coronary artery disease
# 20496       20496                        Angina pectoris STATUS POST
# 20497       20497            Unstable angina 1/86 cath lad stenosis.
# 20541       20541    History of coronary artery bypass surgery in...
# 20595       20595  Of note, the patient had a history of paroxysm...
# 20616       20616    Followup of recent MI and multiple medical p...
# 20631       20631                            Coronary artery disease
# 20645       20645                        Angina pectoris STATUS POST
# 20646       20646            Unstable angina 1/86 cath lad stenosis.
# 20649       20649         S/P MI 12/92 with cardiac cath, stent RCA.
# 20759       20759  Coronary artery disease:  Patient had mildly a...
# 20769       20769                       No MI or symptomatic angina.
# 20863       20863  Coronary disease: patient had a mild posterior...
# 21077       21077                                           ischemic
# 21103       21103  Specifically, she is status post a right fem-p...
# 21109       21109  She does have a strong family history of coron...
# 21110       21110  She has a report of a prior EKG with suggestio...
# 21111       21111  She has never had any evaluation for underlyin...
# 21116       21116  Her past medical history is as noted above inc...
# 21121       21121  As I mentioned previously, her family history ...
# 21135       21135  There is left atrial enlargement and Q-waves i...
# 21136       21136  There are also Q-waves in lead III and aVF, wh...
# 21137       21137  In summary, Ms. Hendricks is a lovely 52-year-...
# 21139       21139  However, I am concerned by her electrocardiogr...
# 21140       21140  As such, I think that it would be wise to bett...
# 21149       21149  This is more in order to give us a sense of th...
# 21222       21222  A/P: 71F w/ MMPs including CAD w/ recent norma...
# 21342       21342  A/P: 71F w/ MMPs including CAD w/ recent norma...
#
#             label        file    Class0    Class1    Class2    Class3  \
# 66     before DCT  110-03.xml  0.001055  0.000730  0.996982  0.001233
# 86     before DCT  110-04.xml  0.000986  0.001878  0.996392  0.000743
# 98     before DCT  110-04.xml  0.000768  0.943808  0.053853  0.001571
# 157    before DCT  110-04.xml  0.001902  0.001069  0.996298  0.000731
# 161    before DCT  110-04.xml  0.004307  0.000988  0.994101  0.000604
# 180     after DCT  111-04.xml  0.001942  0.003586  0.993722  0.000751
# 192    before DCT  111-04.xml  0.001885  0.007107  0.990262  0.000746
# 251         Other  112-03.xml  0.618555  0.000750  0.379248  0.001447
# 253    before DCT  112-03.xml  0.001610  0.000782  0.996431  0.001178
# 291    before DCT  112-04.xml  0.004824  0.000704  0.993678  0.000793
# 342    before DCT  113-04.xml  0.000896  0.968039  0.030459  0.000606
# 419    before DCT  113-05.xml  0.001263  0.001039  0.996949  0.000748
# 439    before DCT  113-05.xml  0.000800  0.000847  0.995860  0.002493
# 542    during DCT  115-04.xml  0.001483  0.001431  0.005238  0.991847
# 576    before DCT  115-04.xml  0.026484  0.083872  0.133888  0.755756
# 577         Other  115-04.xml  0.898425  0.000338  0.100636  0.000602
# 735    before DCT  117-02.xml  0.006927  0.000541  0.991472  0.001061
# 754    before DCT  117-02.xml  0.003686  0.000577  0.994550  0.001187
# 766         Other  117-02.xml  0.004360  0.000588  0.993949  0.001103
# 832    before DCT  117-02.xml  0.607938  0.000633  0.390497  0.000932
# 874    before DCT  118-02.xml  0.004908  0.000561  0.993089  0.001442
# 925         Other  118-04.xml  0.006301  0.000630  0.992279  0.000790
# 935    before DCT  118-04.xml  0.044820  0.000852  0.953391  0.000937
# 976    before DCT  118-05.xml  0.004114  0.201815  0.792763  0.001307
# 1024   before DCT  118-05.xml  0.001594  0.991383  0.001953  0.005070
# 1103   before DCT  118-05.xml  0.001264  0.000448  0.009025  0.989263
# 1150   before DCT  119-02.xml  0.595115  0.000572  0.403018  0.001296
# 1187    after DCT  119-03.xml  0.001806  0.009178  0.988181  0.000835
# 1199   before DCT  119-04.xml  0.910139  0.000297  0.089088  0.000476
# 1214   before DCT  119-04.xml  0.002927  0.000596  0.993207  0.003270
# ...           ...         ...       ...       ...       ...       ...
# 20470  before DCT  268-03.xml  0.001483  0.001431  0.005238  0.991847
# 20475  before DCT  268-03.xml  0.001710  0.000492  0.994962  0.002836
# 20483  before DCT  268-03.xml  0.026484  0.083872  0.133888  0.755756
# 20496  before DCT  268-03.xml  0.001619  0.000487  0.995350  0.002543
# 20497  before DCT  268-03.xml  0.001123  0.000958  0.996903  0.001017
# 20541  before DCT  268-03.xml  0.009810  0.002649  0.986502  0.001040
# 20595       Other  268-03.xml  0.002601  0.001116  0.995679  0.000603
# 20616  before DCT  268-04.xml  0.001820  0.000972  0.996457  0.000751
# 20631  before DCT  268-04.xml  0.026484  0.083872  0.133888  0.755756
# 20645  before DCT  268-04.xml  0.001619  0.000487  0.995350  0.002543
# 20646  before DCT  268-04.xml  0.001123  0.000958  0.996903  0.001017
# 20649  before DCT  268-04.xml  0.000947  0.000814  0.977438  0.020801
# 20759  before DCT  269-01.xml  0.001576  0.000684  0.012327  0.985414
# 20769       Other  269-01.xml  0.015185  0.000713  0.983305  0.000797
# 20863   after DCT  269-02.xml  0.020883  0.002998  0.973222  0.002897
# 21077       Other  269-04.xml  0.999656  0.000021  0.000291  0.000032
# 21103       Other  317-01.xml  0.996807  0.000058  0.003070  0.000065
# 21109       Other  317-01.xml  0.000536  0.997364  0.000781  0.001319
# 21110  before DCT  317-01.xml  0.001357  0.001038  0.996835  0.000770
# 21111  during DCT  317-01.xml  0.001071  0.990682  0.007732  0.000515
# 21116       Other  317-01.xml  0.958045  0.000292  0.041447  0.000215
# 21121       Other  317-01.xml  0.784969  0.000563  0.213874  0.000594
# 21135       Other  317-01.xml  0.003615  0.000805  0.994880  0.000701
# 21136  before DCT  317-01.xml  0.971307  0.000169  0.028327  0.000196
# 21137       Other  317-01.xml  0.510841  0.000634  0.487191  0.001335
# 21139  during DCT  317-01.xml  0.000944  0.012435  0.966904  0.019717
# 21140       Other  317-01.xml  0.000611  0.995337  0.001599  0.002453
# 21149  during DCT  317-01.xml  0.003970  0.838583  0.028846  0.128600
# 21222   after DCT  371-04.xml  0.000822  0.001293  0.996990  0.000895
# 21342  before DCT  371-05.xml  0.000807  0.001261  0.996998  0.000935
#
#       predClass   predLabel
# 66       Class2  during dct
# 86       Class2   after dct
# 98       Class1  before dct
# 157      Class2   after dct
# 161      Class2   after dct
# 180      Class2  before dct
# 192      Class2  before dct
# 251      Class0  during dct
# 253      Class2  during dct
# 291      Class2   after dct
# 342      Class1  before dct
# 419      Class2  before dct
# 439      Class2  before dct
# 542      Class3  before dct
# 576      Class3  before dct
# 577      Class0  during dct
# 735      Class2  during dct
# 754      Class2  during dct
# 766      Class2   after dct
# 832      Class0  during dct
# 874      Class2   after dct
# 925      Class2   after dct
# 935      Class2   after dct
# 976      Class2  before dct
# 1024     Class1  before dct
# 1103     Class3  before dct
# 1150     Class0  during dct
# 1187     Class2  before dct
# 1199     Class0  during dct
# 1214     Class2  during dct
# ...         ...         ...
# 20470    Class3  before dct
# 20475    Class2  during dct
# 20483    Class3  before dct
# 20496    Class2  during dct
# 20497    Class2  during dct
# 20541    Class2   after dct
# 20595    Class2   after dct
# 20616    Class2   after dct
# 20631    Class3  before dct
# 20645    Class2  during dct
# 20646    Class2  during dct
# 20649    Class2   after dct
# 20759    Class3  before dct
# 20769    Class2  during dct
# 20863    Class2   after dct
# 21077    Class0  during dct
# 21103    Class0   after dct
# 21109    Class1   after dct
# 21110    Class2   after dct
# 21111    Class1  before dct
# 21116    Class0   after dct
# 21121    Class0   after dct
# 21135    Class2   after dct
# 21136    Class0   after dct
# 21137    Class0   after dct
# 21139    Class2   after dct
# 21140    Class1  before dct
# 21149    Class1  before dct
# 21222    Class2  before dct
# 21342    Class2  before dct
#
# [725 rows x 10 columns]

# %%
CT_test_labels = CT_combined['label']
CT_pred_labels = CT_combined['predLabel']

# %%
accuracy_score(CT_test_labels, CT_pred_labels)
# Out:
# 0.955260822864615

# %%
print(classification_report(CT_pred_labels, CT_test_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Other       0.99      0.99      0.99     20688
#    after DCT       0.00      0.00      0.00         0
#    after dct       0.00      0.00      0.00       270
#   before DCT       0.00      0.00      0.00         0
#   before dct       0.00      0.00      0.00       329
#   during DCT       0.00      0.00      0.00         0
#   during dct       0.00      0.00      0.00       126
#
#    micro avg       0.96      0.96      0.96     21413
#    macro avg       0.14      0.14      0.14     21413
# weighted avg       0.96      0.96      0.96     21413
# C:\Users\Kalyan\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Kalyan\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
unique_label = np.unique(CT_test_labels)
print(pd.DataFrame(confusion_matrix(CT_test_labels, CT_pred_labels, labels=unique_label), 
                   index=['true:{:}'.format(x) for x in unique_label], 
                   columns=['pred:{:}'.format(x) for x in unique_label]))
# Out:
#                  pred:Other  pred:after DCT  pred:before DCT  pred:during DCT
# true:Other            20455               0                0                0
# true:after DCT            6               0                0                0
# true:before DCT         193               0                0                0
# true:during DCT          34               0                0                0

# %% [markdown]
# Here the consusion matrix shows that all of the CAD classes have been confused with "Other" class in the prediction.  Let's see the examples:

# %%
CT_combined[(CT_combined['label']!='Other') & (CT_combined['predLabel']=='Other')]
# Out:
#        sentenceId                                           sentence  \
# 8               8  HPI:  70 yo M with NIDDM admitted for cath aft...
# 12             12  MIBI was read as positive for moderate to seve...
# 60             60                  The ECG is positive for ischemia.
# 62             62  Findings are consistent with moderate to sever...
# 68             68  \tIschemia: Hx angina, MIBI positive for infer...
# 94             94  The pain does not remind him of his sx prior t...
# 182           182     walking, took 2 nitro and the pain got better.
# 184           184             repeat episode relived by nitro again.
# 198           198  PAST SURGICAL HISTORY:  Angioplasty with multi...
# 257           257  He tells me that he underwent testing at Wheat...
# 289           289  He complained of fatigue and exertional throat...
# 290           290  Cardiac catheterization performed by Dr. Lesli...
# 734           734  Patient reports a history of angina stating th...
# 833           833  Patient does describes episodes of angina that...
# 1025         1025  Preoperative cardiac catheterization on 03/11/...
# 1378         1378  The perfusion scans showed a moderate, reversi...
# 1464         1464  He has been experiencing increasing DOE and ha...
# 1653         1653  The patient had symptoms of dyspnea on exertio...
# 2107         2107  Pt was taken to the cath lab and found to have...
# 2108         2108                               A BMS to RCA lesion.
# 2208         2208  Intervention on acute lesion today and possibl...
# 2255         2255  An emergent cardiac catheterization at that ti...
# 2259         2259  The RCA was large and dominant and had a proxi...
# 2786         2786  The chest did show a healed coronary artery by...
# 2947         2947  The patient had negative troponin studies but ...
# 2950         2950  He had increase in his Lipitor from 20 mg to 8...
# 2951         2951  Dr Gil RNHHe has a long history of cardiac dis...
# 2956         2956  Elevated microalbumin-to renal specialistAller...
# 2969         2969                                              EOMI.
# 3002         3002  HISTORY OF PRESENT ILLNESS:  The patient is a ...
# ...           ...                                                ...
# 18239       18239  ); ECG response to stress was  nondiagnostic f...
# 18278       18278                       FHx:  \tMother: CAD s/p CABG
# 18892       18892      REVIEW OF SYSTEMS:  He denies chest pain now.
# 18923       18923        FINAL DIAGNOSIS:  Unstable angina pectoris.
# 18991       18991  Emergency Medicine with complaints of chest pain.
# 19049       19049  and morphine for his chest pain, and admitted ...
# 19067       19067  female complaining of chest tightness lasting ...
# 19128       19128  comes in today with chest pain, onset iffy whi...
# 19219       19219  PHYSICAL EXAMINATION:  She is afebrile, heart ...
# 19263       19263  CLINICAL IMPRESSION:  Unstable angina with fre...
# 19313       19313    IMPRESSION:  End-stage ischemic cardiomyopathy.
# 19543       19543           Syncope, rule out myocardial infarction.
# 19619       19619  PHYSICAL EXAMINATION:  His blood pressure is 1...
# 20020       20020  The patient states the pain was a 10/10, worse...
# 20114       20114                                 here for her CABG.
# 20138       20138  She states that this pain is similar to her an...
# 20186       20186                 FINAL DIAGNOSIS:  Unstable angina.
# 20207       20207  History of Present Illness:  65 year old RH ge...
# 20460       20460    Since his last visit, the patient has had tw...
# 20499       20499                ETT 3/2091 mild ant./basal ischemia
# 20648       20648               ETT 3/2091 mild ant./basal ischemia.
# 20710       20710  Heent   NC/AT, PERRL, EOMI, O/P clear without ...
# 20713       20713                         Cor   PMI at 5th ICS, MCL.
# 20928       20928  2/1/11 stroke 4/4/12 exercise sestamibi-SAH: S...
# 20932       20932  History of Present Illness: This 73 year-old h...
# 20992       20992  Intro:\t73 yo male s/p CABG with progressive a...
# 21002       21002                                           2)\tCAD
# 21004       21004  i)\tOccluded RCA, subtotal circumflex and 95% ...
# 21006       21006                                          b)\tCABG
# 21016       21016  9)\tBPH  -  reports that he was in the process...
#
#             label        file    Class0    Class1    Class2    Class3  \
# 8      before DCT  110-03.xml  0.999235  0.000022  0.000710  0.000033
# 12     before DCT  110-03.xml  0.995930  0.000060  0.003940  0.000071
# 60     before DCT  110-03.xml  0.985374  0.000127  0.014360  0.000139
# 62     before DCT  110-03.xml  0.999231  0.000032  0.000698  0.000039
# 68     before DCT  110-03.xml  0.999664  0.000042  0.000254  0.000040
# 94     before DCT  110-04.xml  0.804428  0.000567  0.194260  0.000744
# 182    before DCT  111-04.xml  0.999683  0.000022  0.000273  0.000022
# 184    before DCT  111-04.xml  0.999844  0.000016  0.000124  0.000016
# 198    before DCT  111-04.xml  0.802693  0.000435  0.196281  0.000591
# 257    before DCT  112-03.xml  0.997462  0.000051  0.002432  0.000056
# 289    before DCT  112-04.xml  0.065460  0.000947  0.932398  0.001195
# 290    before DCT  112-04.xml  0.002702  0.001032  0.995647  0.000619
# 734    before DCT  117-02.xml  0.995274  0.000052  0.004599  0.000076
# 833    before DCT  117-02.xml  0.996420  0.000050  0.003471  0.000059
# 1025   before DCT  118-05.xml  0.001723  0.001306  0.996352  0.000619
# 1378   before DCT  131-03.xml  0.996835  0.000070  0.003032  0.000063
# 1464   before DCT  131-03.xml  0.999761  0.000019  0.000201  0.000018
# 1653   before DCT  131-05.xml  0.001513  0.000703  0.995539  0.002246
# 2107   during DCT  134-04.xml  0.000827  0.001316  0.996886  0.000971
# 2108   during DCT  134-04.xml  0.999814  0.000017  0.000152  0.000017
# 2208   during DCT  134-04.xml  0.715567  0.000482  0.282975  0.000976
# 2255   before DCT  134-05.xml  0.999253  0.000028  0.000692  0.000027
# 2259   before DCT  134-05.xml  0.685517  0.000603  0.313073  0.000807
# 2786   before DCT  137-01.xml  0.116299  0.000798  0.880832  0.002070
# 2947   before DCT  137-04.xml  0.999606  0.000021  0.000350  0.000022
# 2950   before DCT  137-04.xml  0.991424  0.000071  0.008327  0.000177
# 2951   before DCT  137-04.xml  0.962441  0.000186  0.037140  0.000233
# 2956   before DCT  137-04.xml  0.999759  0.000021  0.000176  0.000044
# 2969   before DCT  137-04.xml  0.997380  0.000054  0.002345  0.000221
# 3002    after DCT  138-03.xml  0.999104  0.000039  0.000822  0.000035
# ...           ...         ...       ...       ...       ...       ...
# 18239  before DCT  260-05.xml  0.085018  0.000659  0.912901  0.001422
# 18278  before DCT  260-05.xml  0.999790  0.000019  0.000167  0.000024
# 18892  before DCT  263-02.xml  0.999660  0.000021  0.000296  0.000024
# 18923  before DCT  263-02.xml  0.997325  0.000040  0.002575  0.000060
# 18991  during DCT  263-04.xml  0.999626  0.000021  0.000329  0.000024
# 19049  during DCT  263-04.xml  0.999684  0.000023  0.000269  0.000024
# 19067  before DCT  264-01.xml  0.999744  0.000017  0.000214  0.000025
# 19128  during DCT  264-02.xml  0.999598  0.000022  0.000354  0.000026
# 19219  before DCT  264-03.xml  0.999696  0.000024  0.000253  0.000027
# 19263  during DCT  264-03.xml  0.992736  0.000071  0.007105  0.000087
# 19313  during DCT  264-04.xml  0.999644  0.000020  0.000312  0.000024
# 19543  before DCT  265-03.xml  0.999640  0.000021  0.000314  0.000025
# 19619  before DCT  265-04.xml  0.999506  0.000031  0.000433  0.000030
# 20020  before DCT  267-02.xml  0.011360  0.000706  0.986996  0.000938
# 20114  before DCT  267-03.xml  0.076178  0.001304  0.921567  0.000951
# 20138  during DCT  267-04.xml  0.046856  0.000866  0.950505  0.001773
# 20186  during DCT  267-04.xml  0.999076  0.000029  0.000861  0.000034
# 20207   after DCT  268-01.xml  0.997587  0.000052  0.002293  0.000069
# 20460  before DCT  268-03.xml  0.999781  0.000020  0.000180  0.000018
# 20499  before DCT  268-03.xml  0.999440  0.000023  0.000499  0.000038
# 20648  before DCT  268-04.xml  0.998675  0.000033  0.001245  0.000047
# 20710  before DCT  268-04.xml  0.999141  0.000027  0.000796  0.000035
# 20713  before DCT  268-04.xml  0.999822  0.000017  0.000142  0.000019
# 20928  before DCT  269-03.xml  0.998121  0.000040  0.001766  0.000073
# 20932  before DCT  269-03.xml  0.994947  0.000073  0.004900  0.000079
# 20992  before DCT  269-04.xml  0.999846  0.000017  0.000119  0.000019
# 21002  before DCT  269-04.xml  0.999640  0.000037  0.000225  0.000098
# 21004  before DCT  269-04.xml  0.897441  0.003123  0.012346  0.087090
# 21006  before DCT  269-04.xml  0.999580  0.000034  0.000263  0.000123
# 21016  before DCT  269-04.xml  0.999573  0.000051  0.000254  0.000122
#
#       predClass predLabel
# 8        Class0     Other
# 12       Class0     Other
# 60       Class0     Other
# 62       Class0     Other
# 68       Class0     Other
# 94       Class0     Other
# 182      Class0     Other
# 184      Class0     Other
# 198      Class0     Other
# 257      Class0     Other
# 289      Class2     Other
# 290      Class2     Other
# 734      Class0     Other
# 833      Class0     Other
# 1025     Class2     Other
# 1378     Class0     Other
# 1464     Class0     Other
# 1653     Class2     Other
# 2107     Class2     Other
# 2108     Class0     Other
# 2208     Class0     Other
# 2255     Class0     Other
# 2259     Class0     Other
# 2786     Class2     Other
# 2947     Class0     Other
# 2950     Class0     Other
# 2951     Class0     Other
# 2956     Class0     Other
# 2969     Class0     Other
# 3002     Class0     Other
# ...         ...       ...
# 18239    Class2     Other
# 18278    Class0     Other
# 18892    Class0     Other
# 18923    Class0     Other
# 18991    Class0     Other
# 19049    Class0     Other
# 19067    Class0     Other
# 19128    Class0     Other
# 19219    Class0     Other
# 19263    Class0     Other
# 19313    Class0     Other
# 19543    Class0     Other
# 19619    Class0     Other
# 20020    Class2     Other
# 20114    Class2     Other
# 20138    Class2     Other
# 20186    Class0     Other
# 20207    Class0     Other
# 20460    Class0     Other
# 20499    Class0     Other
# 20648    Class0     Other
# 20710    Class0     Other
# 20713    Class0     Other
# 20928    Class0     Other
# 20932    Class0     Other
# 20992    Class0     Other
# 21002    Class0     Other
# 21004    Class0     Other
# 21006    Class0     Other
# 21016    Class0     Other
#
# [233 rows x 10 columns]
